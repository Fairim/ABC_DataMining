# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ABC_DataMining/blob/main/06-01-2025-%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B8_%D0%BF%D1%80%D0%BE%D0%B3%D0%BD%D0%BE%D0%B7%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B2%D0%B5%D0%B1_%D1%82%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B0_%D1%81%D1%80%D0%B0%D0%B2%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BA%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D1%85%2C_%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D1%8B%D1%85_%D0%B8_%D0%B3%D0%BB%D1%83%D0%B1%D0%BE%D0%BA%D0%B8%D1%85_%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D0%BE%D0%B2_%D0%B4%D0%BB%D1%8F_%D0%BE%D0%BF%D1%82%D0%B8%D0%BC%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D0%B8_%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D1%8C%D1%81%D0%BA%D0%BE%D0%B9_%D0%B0%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D1%81%D1%82%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Анализ и прогнозирование веб-трафика: сравнение классических, машинных и глубоких методов для оптимизации пользовательской активности**
#
#
# ### **Аннотация**
#
# В статье проводится сравнительный анализ классических, машинных и глубоких методов для анализа и прогнозирования веб-трафика с целью оптимизации пользовательской активности. Рассматриваются два основных подхода: прогнозирование без учета внешних факторов, основанное на исторических данных временного ряда, и прогнозирование с учетом внешних факторов, таких как маркетинговые кампании, сезонность и погодные условия. В исследовании применяются методы ARIMA, SARIMAX, XGBoost, LightGBM, LSTM, GRU и CNN, каждый из которых оценивается по таким метрикам, как среднее абсолютное отклонение (MAE), среднеквадратичная ошибка (RMSE) и средняя абсолютная процентная ошибка (MAPE).
#
#
# **Ключевые слова:** временные ряды, веб-трафик, прогнозирование, SARIMAX, XGBoost, LSTM, GRU, точность прогнозов, сезонность, аномалии в данных, оптимизация маркетинговых каналов.
#
# #### **Введение**
#
# В условиях цифровой трансформации веб-сайты стали ключевым инструментом для достижения бизнес-целей, таких как увеличение конверсий, улучшение пользовательского опыта и повышение прибыльности. Однако анализ производительности веб-сайтов сопряжен с рядом вызовов, включая сезонные колебания трафика, наличие шумов в данных и сложность прогнозирования в условиях нестабильности. Временные ряды, отражающие данные о трафике и пользовательской активности, позволяют не только выявить ключевые тренды и сезонные паттерны, но и обнаружить аномалии, что делает их ценным инструментом для прогнозирования и принятия решений.
#
# Согласно исследованию Vlahogianni, Karlaftis и Golias (2014), точное прогнозирование временных рядов, таких как веб-трафик, требует учета как внутренних закономерностей данных, так и внешних факторов, которые могут влиять на динамику [1]. В условиях растущей конкуренции на цифровых платформах эта задача становится критически важной для эффективного управления ресурсами, планирования маркетинговых кампаний и минимизации издержек.
#
# Целью данной статьи является проведение сравнительного анализа классических, машинных и глубоких методов для анализа и прогнозирования веб-трафика с акцентом на повышение уровня вовлеченности пользователей. В работе рассматриваются два основных подхода:
# 1. **Прогнозирование без учета внешних факторов**, где модель строится исключительно на основе исторических данных временного ряда.
# 2. **Прогнозирование с учетом внешних факторов**, где учитываются дополнительные переменные, такие как маркетинговые кампании, сезонность, погодные условия и другие влияющие факторы.
#
# Для решения задачи прогнозирования без учета внешних факторов используется функциональная зависимость, отражающая связь между прошлыми и будущими значениями временного ряда:
# $$
# Z(t) = F(Z(t-1), Z(t-2), Z(t-3), \dots) + \varepsilon_t,
# $$
# где $Z(t)$ — значения временного ряда в момент времени $t$, а $\varepsilon_t$ — ошибка модели. Основная задача заключается в минимизации среднего абсолютного отклонения (MAE) между прогнозируемыми и фактическими значениями:
# $$
# E = \frac{1}{P} \sum_{t=T+1}^{T+P} |\varepsilon_t| \to \min.
# $$
#
# Эта формула является стандартной для авторегрессионных моделей (AR), которые широко используются в прогнозировании временных рядов. Чучуева И.А. (2012) также использует аналогичные подходы в своей работе, где рассматривается прогнозирование на основе выборки максимального подобия [2].
#
# Для прогнозирования с учетом внешних факторов модель расширяется за счет включения дополнительных переменных $X_1(t), X_2(t), \dots, X_S(t)$, которые могут влиять на исходный временной ряд:
# $$
# Z(t) = F(Z(t-1), Z(t-2), \dots, X_1(t), X_1(t-1), \dots, X_S(t), X_S(t-1), \dots) + \varepsilon_t.
# $$
# В этом случае задача также сводится к минимизации ошибки прогноза $E$, но с учетом дополнительных факторов. Такие модели, как SARIMAX, успешно применяются для учета внешних факторов в прогнозировании временных рядов [2].
#
# Новизна исследования заключается в комплексном подходе, который объединяет классические методы анализа временных рядов, современные методы машинного обучения и глубокого обучения, что позволяет учитывать как внутренние закономерности данных, так и внешние факторы, влияющие на веб-трафик. На основе полученных данных предложены практические рекомендации по оптимизации маркетинговых стратегий и улучшению пользовательского опыта.
#
#
#
# #### **Литературный обзор**
#
# Прогнозирование временных рядов, включая веб-трафик, является активно исследуемой областью, что обусловлено его важностью для бизнеса и управления ресурсами. В работе Vlahogianni et al. (2014) подчеркивается, что точное прогнозирование требует учета как внутренних закономерностей данных, так и внешних факторов, таких как маркетинговые кампании, сезонность и экономические изменения [1]. Авторы отмечают, что классические методы, такие как ARIMA, эффективны для стационарных данных, но их применение ограничено в условиях нестабильности и нелинейных зависимостей.
#
# Чучуева И.А. (2012) в своем исследовании предложила метод прогнозирования на основе выборки максимального подобия, который показал высокую точность для стационарных временных рядов [2]. Однако в условиях нестабильности и наличия шумов в данных этот метод может быть недостаточно точным, что подчеркивает необходимость использования более гибких подходов.
#
# Современные методы машинного обучения, такие как XGBoost и LightGBM, демонстрируют высокую точность и устойчивость к шумам. В работе Chen и Guestrin (2016) представлен метод XGBoost, который сочетает в себе высокую скорость обработки данных и способность учитывать сложные зависимости [3]. Однако авторы отмечают, что такие методы требуют тщательной настройки гиперпараметров, что может быть ресурсоемким процессом.
#
# Методы глубокого обучения, такие как LSTM и GRU, эффективны для анализа сложных временных рядов. Hochreiter и Schmidhuber (1997) предложили архитектуру LSTM, которая способна учитывать долгосрочные зависимости в данных [4]. Однако их применение ограничено высокой вычислительной сложностью и необходимостью больших объемов данных. В исследовании Zhang et al. (2018) была предложена гибридная модель, сочетающая методы машинного обучения и глубокого обучения, которая показала высокую точность прогнозирования в условиях нестационарных данных [5].
#
# Smyl (2020) предложил метод, основанный на комбинации экспоненциального сглаживания и глубокого обучения, который продемонстрировал высокую эффективность для прогнозирования временных рядов с сильной сезонностью [6]. Этот подход позволяет учитывать как сезонные колебания, так и долгосрочные тренды, что делает его особенно полезным для анализа веб-трафика.
#
# Таким образом, современные исследования показывают, что для точного прогнозирования веб-трафика необходимо комбинировать различные подходы, учитывая как внутренние закономерности данных, так и внешние факторы. Это позволяет повысить точность прогнозов и адаптировать модели к изменяющимся условиям.
#
#
#
# #### **Методы исследования**
#
# В рамках данного исследования применяются следующие методы анализа и прогнозирования временных рядов:
#
# 1. **Классические методы**:
#    - ARIMA (Autoregressive Integrated Moving Average)
#    - SARIMAX (Seasonal ARIMA with Exogenous Variables)
#    - VAR (Vector Autoregression)
#    - SVAR (Structural Vector Autoregression)
#
# 2. **Методы машинного обучения**:
#    - XGBoost (Extreme Gradient Boosting)
#    - LightGBM
#    - Random Forest
#
# 3. **Методы глубокого обучения**:
#    - LSTM (Long Short-Term Memory)
#    - GRU (Gated Recurrent Unit)
#    - CNN (Convolutional Neural Networks)
#
# Каждый из этих методов имеет свои преимущества и недостатки при анализе временных рядов, что делает их применимыми в различных сценариях. В таблице ниже приведены ключевые характеристики каждого метода.
#
#
#
# #### **Сравнение подходов**
#
# | **Метод**         | **Преимущества**                                                                 | **Недостатки**                                                                 |
# |--|-|--|
# | **ARIMA**          | Простота, интерпретируемость, подходит для линейных зависимостей.                | Не учитывает сезонность, требует стационарности данных.                        |
# | **SARIMAX**        | Учет сезонности и внешних факторов.                                              | Сложность настройки, медленная работа на больших данных.                       |
# | **VAR**            | Учет взаимосвязей между несколькими временными рядами.                          | Требует большого объема данных для оценки параметров.                          |
# | **SVAR**           | Возможность анализа причинно-следственных связей.                               | Сложность настройки и интерпретации.                                           |
# | **XGBoost**        | Высокая точность, устойчивость к шумам.                                          | Требует тщательной настройки гиперпараметров.                                  |
# | **LightGBM**       | Быстрая обработка данных, эффективен для категориальных признаков.               | Склонность к переобучению на небольших данных.                                 |
# | **Random Forest**  | Устойчивость к переобучению, простота интерпретации.                             | Менее точный по сравнению с бустинговыми методами.                             |
# | **LSTM**           | Учет долгосрочных зависимостей, высокая точность для сложных данных.             | Требует больших объемов данных, высокая вычислительная сложность.              |
# | **GRU**            | Быстрее обучается по сравнению с LSTM.                                           | Менее точный для очень сложных зависимостей.                                   |
# | **CNN**            | Эффективен для выявления локальных паттернов.                                    | Требует специфической предобработки данных.                                    |
#
#
#
# #### **Практическая значимость**
#
# Результаты данного исследования могут быть использованы для:
# 1. Оптимизации маркетинговых стратегий на основе точных прогнозов веб-трафика.
# 2. Улучшения пользовательского опыта за счет анализа поведения пользователей.
# 3. Повышения конверсии на веб-сайтах за счет своевременного реагирования на изменения трафика.
# 4. Автоматизации процессов принятия решений в системах управления веб-трафиком.
#
#
#
# #### **Ограничения исследования**
#
# 1. Использование данных только с одного веб-сайта может повлиять на обобщаемость результатов.
# 2. Методы глубокого обучения требуют больших объемов данных и вычислительных ресурсов, что может быть ограничением для небольших компаний.
# 3. Внешние факторы, такие как изменения в алгоритмах поисковых систем или глобальные события, могут влиять на точность прогнозов.
#
#
#
#
# Таким образом, данное исследование направлено на решение актуальной задачи прогнозирования веб-трафика с использованием современных методов анализа данных. Ожидается, что результаты исследования позволят предложить эффективные подходы для оптимизации пользовательской активности и повышения конверсии на веб-сайтах. В дальнейшем будут рассмотрены классические, машинные и глубокие методы прогнозирования, а также проведен их сравнительный анализ на реальных данных.

# %% [markdown]
# ### **Предобработка данных**
#
# Предобработка данных — это критически важный этап анализа, который включает в себя очистку данных, обработку пропущенных значений, преобразование категориальных переменных, нормализацию и стандартизацию данных. Ниже представлен подробный и структурированный подход к предобработке данных, включающий исследование данных, обработку категориальных переменных, создание временных признаков, нормализацию, корреляционный анализ, сегментацию данных и подготовку данных для моделей машинного обучения.
#
# Импорт библиотек

# %%
# !pip install category_encoders
# !pip install pmdarima
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.10/dist-packages (2.6.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.6.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.10/dist-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.6.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split, TimeSeriesSplit, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.tsa.vector_ar.svar_model import SVAR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import LabelEncoder
from pmdarima import auto_arima
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy.stats import shapiro
import joblib

# Импорты для глубокого обучения через TensorFlow 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# #### **1. Исследование данных (Exploratory Data Analysis, EDA)**
#
# Исследование данных позволяет получить первичное представление о структуре данных, выявить аномалии, пропущенные значения и закономерности.
#
# ##### **1.1. Изучение структуры данных**
# Первым шагом является загрузка данных и изучение их структуры, включая типы переменных, наличие пропущенных значений и общую статистику.

# %%
# Загрузка данных
data = pd.read_csv('/content/drive/MyDrive/Science/data-export.csv')

# Переименуем колонки
data.columns = [
    'Session primary channel group', 'Date + hour (YYYYMMDDHH)', 'Users', 'Sessions',
    'Engaged sessions', 'Average engagement time per session', 'Engaged sessions per user',
    'Events per session', 'Engagement rate', 'Event count'
]

# Удалим первую строку, если она содержит некорректные данные
data = data.drop(0)

# Преобразуем колонки к правильным типам данных
data['Date + hour (YYYYMMDDHH)'] = pd.to_datetime(data['Date + hour (YYYYMMDDHH)'], format='%Y%m%d%H')
numeric_columns = ['Users', 'Sessions', 'Engaged sessions', 'Average engagement time per session',
                   'Engaged sessions per user', 'Events per session', 'Engagement rate', 'Event count']
data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric)

# Проверка данных
data.head()
# Out:
#   Session primary channel group Date + hour (YYYYMMDDHH)  Users  Sessions  \
# 1                        Direct      2024-04-16 23:00:00    237       300
# 2                Organic Social      2024-04-17 19:00:00    208       267
# 3                        Direct      2024-04-17 23:00:00    188       233
# 4                Organic Social      2024-04-17 18:00:00    187       256
# 5                Organic Social      2024-04-17 20:00:00    175       221
#
#    Engaged sessions  Average engagement time per session  \
# 1               144                            47.526667
# 2               132                            32.097378
# 3               115                            39.939914
# 4               125                            32.160156
# 5               112                            46.918552
#
#    Engaged sessions per user  Events per session  Engagement rate  Event count
# 1                   0.607595            4.673333         0.480000         1402
# 2                   0.634615            4.295880         0.494382         1147
# 3                   0.611702            4.587983         0.493562         1069
# 4                   0.668449            4.078125         0.488281         1044
# 5                   0.640000            4.529412         0.506787         1001

# %%
# Изучение структуры данных
print(data.info())

# Основные статистические характеристики
print(data.describe())

# Проверка пропущенных значений
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 1 to 3182
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Session primary channel group        3182 non-null   object
#  1   Date + hour (YYYYMMDDHH)             3182 non-null   datetime64[ns]
#  2   Users                                3182 non-null   int64
#  3   Sessions                             3182 non-null   int64
#  4   Engaged sessions                     3182 non-null   int64
#  5   Average engagement time per session  3182 non-null   float64
#  6   Engaged sessions per user            3182 non-null   float64
#  7   Events per session                   3182 non-null   float64
#  8   Engagement rate                      3182 non-null   float64
#  9   Event count                          3182 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(1)
# memory usage: 248.7+ KB
# None
#             Date + hour (YYYYMMDDHH)        Users     Sessions  \
# count                           3182  3182.000000  3182.000000
# mean   2024-04-20 01:17:07.278441216    41.935889    51.192646
# min              2024-04-06 00:00:00     0.000000     1.000000
# 25%              2024-04-13 02:15:00    20.000000    24.000000
# 50%              2024-04-20 02:00:00    42.000000    51.000000
# 75%              2024-04-26 22:00:00    60.000000    71.000000
# max              2024-05-03 23:00:00   237.000000   300.000000
# std                              NaN    29.582258    36.919962
#
#        Engaged sessions  Average engagement time per session  \
# count       3182.000000                          3182.000000
# mean          28.325581                            66.644581
# min            0.000000                             0.000000
# 25%           13.000000                            32.103034
# 50%           27.000000                            49.020202
# 75%           41.000000                            71.487069
# max          144.000000                          4525.000000
# std           20.650569                           127.200659
#
#        Engaged sessions per user  Events per session  Engagement rate  \
# count                3182.000000         3182.000000      3182.000000
# mean                    0.606450            4.675969         0.503396
# min                     0.000000            1.000000         0.000000
# 25%                     0.561404            3.750000         0.442902
# 50%                     0.666667            4.410256         0.545455
# 75%                     0.750000            5.217690         0.633333
# max                     2.000000           56.000000         1.000000
# std                     0.264023            2.795228         0.228206
#
#        Event count
# count  3182.000000
# mean    242.272470
# min       1.000000
# 25%     103.000000
# 50%     226.000000
# 75%     339.000000
# max    1402.000000
# std     184.440313
# Session primary channel group          0
# Date + hour (YYYYMMDDHH)               0
# Users                                  0
# Sessions                               0
# Engaged sessions                       0
# Average engagement time per session    0
# Engaged sessions per user              0
# Events per session                     0
# Engagement rate                        0
# Event count                            0
# dtype: int64

# %% [markdown]
# Из представленных результатов видно, что набор данных характеризуется высокой степенью полноты и отсутствием пропущенных значений, что делает его пригодным для углубленного анализа. Однако наблюдаются значительные вариации в данных, особенно в переменной `Average engagement time per session`, где зафиксированы экстремальные значения (максимум: 4525 секунд). Это может указывать на наличие выбросов, которые требуют дополнительного исследования для понимания их природы и влияния на общие результаты.
#
# Средний уровень вовлеченности составляет 50.34%, что свидетельствует о умеренной вовлеченности пользователей. При этом среднее количество активных сессий на пользователя (`Engaged sessions per user`) равно 0.61, что указывает на то, что более половины пользователей не проявляют высокой активности. Это может быть связано с различными факторами, такими как качество контента, эффективность маркетинговых каналов или особенности пользовательского опыта.
#
# Также стоит отметить, что среднее количество событий на сессию (`Events per session`) составляет 4.68, что может свидетельствовать о достаточно высокой активности пользователей в рамках одной сессии. Однако максимальное значение (56 событий) указывает на наличие аномально активных сессий, которые могут быть связаны с ботовой активностью или другими внешними факторами.

# %% [markdown]
# ##### **1.2. Визуализация распределений**
# Для анализа распределения числовых переменных используются гистограммы и ящики с усами (box plots), которые помогают выявить выбросы и асимметрию.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Гистограммы для числовых переменных
data[numeric_columns].hist(bins=30, figsize=(15, 10))
plt.suptitle('Распределение числовых переменных')
plt.show()

# Ящики с усами для выявления выбросов
plt.figure(figsize=(12, 8))
sns.boxplot(data=data[numeric_columns])
plt.title('Ящики с усами для числовых переменных')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ###1.3. Визуализация данные

# %%
# Переименование колонки
data.rename(columns={'Date + hour (YYYYMMDDHH)': 'DateTime'}, inplace=True)
# Сортировка данных по времени (на всякий случай)
data = data.sort_values(by='DateTime')
# Настройка стиля графиков
sns.set(style="whitegrid")

# График количества пользователей и сессий
plt.figure(figsize=(12, 6))
plt.plot(data['DateTime'], data['Users'], label='Users', marker='o')
plt.plot(data['DateTime'], data['Sessions'], label='Sessions', marker='o')
plt.title('Users and Sessions Over Time')
plt.xlabel('DateTime')
plt.ylabel('Count')
plt.legend()
plt.show()

# График вовлеченных сессий и среднего времени вовлечения
plt.figure(figsize=(12, 6))
plt.plot(data['DateTime'], data['Engaged sessions'], label='Engaged Sessions', marker='o')
plt.plot(data['DateTime'], data['Average engagement time per session'], label='Average Engagement Time', marker='o')
plt.title('Engaged Sessions and Average Engagement Time Over Time')
plt.xlabel('DateTime')
plt.ylabel('Count / Time (seconds)')
plt.legend()
plt.show()

# График вовлеченных сессий на пользователя и событий на сессию
plt.figure(figsize=(12, 6))
plt.plot(data['DateTime'], data['Engaged sessions per user'], label='Engaged Sessions per User', marker='o')
plt.plot(data['DateTime'], data['Events per session'], label='Events per Session', marker='o')
plt.title('Engaged Sessions per User and Events per Session Over Time')
plt.xlabel('DateTime')
plt.ylabel('Count')
plt.legend()
plt.show()

# График уровня вовлеченности
plt.figure(figsize=(12, 6))
plt.plot(data['DateTime'], data['Engagement rate'], label='Engagement Rate', marker='o')
plt.title('Engagement Rate Over Time')
plt.xlabel('DateTime')
plt.ylabel('Rate')
plt.legend()
plt.show()

# %% [markdown]
# ### **1.4. Удаление выбросов**
# Выбросы могут искажать результаты моделирования. Их можно удалить или заменить.
#
# #### Примеры:
# - **Удаление выбросов на основе межквартильного размаха (IQR)**:

# %%
# Функция для обработки выбросов и визуализации
def handle_outliers_and_visualize(data, column):
    # Вычисляем квартили и границы
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Визуализация до обработки выбросов
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.boxplot(data[column])
    plt.title(f'До обработки выбросов ({column})')
    plt.xlabel(column)

    # Обрезаем выбросы
    data[column] = np.where(data[column] > upper_bound, upper_bound, data[column])
    data[column] = np.where(data[column] < lower_bound, lower_bound, data[column])

    # Визуализация после обработки выбросов
    plt.subplot(1, 2, 2)
    sns.boxplot(data[column])
    plt.title(f'После обработки выбросов ({column})')
    plt.xlabel(column)

    plt.tight_layout()
    plt.show()

# Обработка и визуализация для 'Event count'
handle_outliers_and_visualize(data, 'Event count')

# Обработка и визуализация для 'Average engagement time per session'
handle_outliers_and_visualize(data, 'Average engagement time per session')

# Вывод обработанных данных
print("Обработанные данные:")
data.head(5)
# Out:
# Обработанные данные:
#      Session primary channel group   DateTime  Users  Sessions  \
# 2942                    Unassigned 2024-04-06      1         1
# 766                         Direct 2024-04-06     60        66
# 2228                      Referral 2024-04-06     24        39
# 637                 Organic Social 2024-04-06     65       108
# 1329                Organic Search 2024-04-06     47        56
#
#       Engaged sessions  Average engagement time per session  \
# 2942                 0                             0.000000
# 766                 40                            97.590909
# 2228                19                            95.256410
# 637                 46                            19.861111
# 1329                41                            62.642857
#
#       Engaged sessions per user  Events per session  Engagement rate  \
# 2942                   0.000000            2.000000         0.000000
# 766                    0.666667            4.030303         0.606061
# 2228                   0.791667            3.871795         0.487179
# 637                    0.707692            3.898148         0.425926
# 1329                   0.872340            4.250000         0.732143
#
#       Event count
# 2942          2.0
# 766         266.0
# 2228        151.0
# 637         421.0
# 1329        238.0

# %% [markdown]
# ##### **1.5. Проверка пропущенных значений**
# Пропущенные значения могут исказить результаты анализа. В зависимости от их природы, применяются различные стратегии заполнения.

# %%
# Проверка пропущенных значений
print(data.isnull().sum())

# Заполнение пропущенных значений средними значениями
data.fillna(data[numeric_columns].mean(), inplace=True)
# Out:
# Session primary channel group          0
# DateTime                               0
# Users                                  0
# Sessions                               0
# Engaged sessions                       0
# Average engagement time per session    0
# Engaged sessions per user              0
# Events per session                     0
# Engagement rate                        0
# Event count                            0
# dtype: int64

# %% [markdown]
# #### **2. Обработка категориальных переменных**
#
# Категориальные переменные, такие как `Session primary channel group`, требуют преобразования в числовой формат для использования в моделях машинного обучения. Одним из наиболее распространенных методов является One-Hot Encoding.
#
# ##### **2.1. One-Hot Encoding**
# One-Hot Encoding преобразует категориальные переменные в бинарные векторы, где каждая категория представляется отдельным столбцом. Это позволяет избежать введения искусственной порядковой зависимости между категориями.

# %%
# Target Encoding (для SARIMAX)
from category_encoders import TargetEncoder

# One-Hot Encoding
data = pd.get_dummies(data, columns=['Session primary channel group'], drop_first=True)

# Label Encoding (для LightGBM)
label_encoder = LabelEncoder()
if 'Session primary channel group' in data.columns:
  data['Session primary channel group_encoded'] = label_encoder.fit_transform(data['Session primary channel group'])

target_encoder = TargetEncoder()
if 'Session primary channel group' in data.columns:
  data['Session primary channel group_encoded_target'] = target_encoder.fit_transform(data['Session primary channel group'], data['Engagement rate'])

# %% [markdown]
# **Преимущества One-Hot Encoding:**
# 1. **Отсутствие искусственной порядковой зависимости:** Категории не получают числовых значений, которые могут быть интерпретированы как имеющие порядок.
# 2. **Совместимость с моделями:** Большинство алгоритмов машинного обучения лучше работают с бинарными признаками.
# 3. **Упрощение интерпретации:** Каждая категория представлена отдельным признаком, что делает данные более прозрачными.
#
#
#
# #### **3. Создание временных признаков**
#
# Для анализа временных рядов важно извлечь признаки из даты и времени, такие как час, день недели и месяц. Это позволяет учитывать временные закономерности.

# %%
# Преобразование колонки в формат datetime, если это еще не сделано
data['DateTime'] = pd.to_datetime(data['DateTime'], format='%Y%m%d%H')

# Извлечение признаков из даты и времени
data['Hour'] = data['DateTime'].dt.hour
data['Day_of_week'] = data['DateTime'].dt.dayofweek  # Понедельник = 0, Воскресенье = 6
data['Month'] = data['DateTime'].dt.month
data.head(5)
# Out:
#        DateTime  Users  Sessions  Engaged sessions  \
# 2942 2024-04-06      1         1                 0
# 766  2024-04-06     60        66                40
# 2228 2024-04-06     24        39                19
# 637  2024-04-06     65       108                46
# 1329 2024-04-06     47        56                41
#
#       Average engagement time per session  Engaged sessions per user  \
# 2942                             0.000000                   0.000000
# 766                             97.590909                   0.666667
# 2228                            95.256410                   0.791667
# 637                             19.861111                   0.707692
# 1329                            62.642857                   0.872340
#
#       Events per session  Engagement rate  Event count  \
# 2942            2.000000         0.000000          2.0
# 766             4.030303         0.606061        266.0
# 2228            3.871795         0.487179        151.0
# 637             3.898148         0.425926        421.0
# 1329            4.250000         0.732143        238.0
#
#       Session primary channel group_Email  \
# 2942                                False
# 766                                 False
# 2228                                False
# 637                                 False
# 1329                                False
#
#       Session primary channel group_Organic Search  \
# 2942                                         False
# 766                                          False
# 2228                                         False
# 637                                          False
# 1329                                          True
#
#       Session primary channel group_Organic Social  \
# 2942                                         False
# 766                                          False
# 2228                                         False
# 637                                           True
# 1329                                         False
#
#       Session primary channel group_Organic Video  \
# 2942                                        False
# 766                                         False
# 2228                                        False
# 637                                         False
# 1329                                        False
#
#       Session primary channel group_Referral  \
# 2942                                   False
# 766                                    False
# 2228                                    True
# 637                                    False
# 1329                                   False
#
#       Session primary channel group_Unassigned  Hour  Day_of_week  Month
# 2942                                      True     0            5      4
# 766                                      False     0            5      4
# 2228                                     False     0            5      4
# 637                                      False     0            5      4
# 1329                                     False     0            5      4

# %% [markdown]
# #### **4. Нормализация и стандартизация данных**
#
# Нормализация и стандартизация данных необходимы для методов машинного обучения, чувствительных к масштабу данных. Это особенно важно для алгоритмов, основанных на расстояниях.
#
# ##### **4.1. Стандартизация**
# Стандартизация преобразует данные к среднему значению 0 и стандартному отклонению 1.

# %%
# Стандартизация числовых переменных
#scaler = StandardScaler()
#data[numeric_columns] = scaler.fit_transform(data[numeric_columns])

# %% [markdown]
# ##### **4.2. Нормализация**
# Нормализация преобразует данные к диапазону [0, 1].

# %%
# Нормализация числовых переменных
#scaler = MinMaxScaler()
#data[numeric_columns] = scaler.fit_transform(data[numeric_columns])

# %% [markdown]
# #### **5. Корреляционный анализ**
#
# Корреляционный анализ позволяет выявить линейные зависимости между переменными и исключить мультиколлинеарность.
#
# ##### **5.1. Матрица корреляции**
# Для визуализации корреляций используется тепловая карта.

# %%
# Расчет корреляционной матрицы
corr_matrix = data[numeric_columns].corr()

# Визуализация тепловой карты
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Матрица корреляции')
plt.show()

# %% [markdown]
# ### **Анализ корреляционной матрицы и рекомендации по выбору признаков для моделирования**
#
# На основе анализа корреляционной матрицы можно сделать следующие выводы, которые помогут оптимизировать выбор признаков для различных методов моделирования: классических, машинного обучения и глубокого обучения.
#
#
#
# #### **1. Высокая степень корреляции**
#
# В ходе анализа выявлена сильная положительная корреляция между следующими переменными:
# - **Пользователи (Users)** и **Сессии (Sessions)** (\( r = 0.989 \)).
# - **Пользователи (Users)** и **Активные сессии (Engaged sessions)** (\( r = 0.974 \)).
# - **Пользователи (Users)** и **Количество событий (Event count)** (\( r = 0.957 \)).
# - **Сессии (Sessions)** и **Активные сессии (Engaged sessions)** (\( r = 0.957 \)).
# - **Сессии (Sessions)** и **Количество событий (Event count)** (\( r = 0.953 \)).
# - **Активные сессии (Engaged sessions)** и **Количество событий (Event count)** (\( r = 0.962 \)).
#
# **Рекомендации:**
# - Для **классических методов (ARIMA, SARIMAX)**: Рекомендуется использовать только один из сильно коррелирующих признаков (например, **Users**) во избежание мультиколлинеарности. В случае применения SARIMAX целесообразно включение внешних переменных, таких как маркетинговые кампании или сезонные факторы.
# - Для **методов машинного обучения (XGBoost, LightGBM, Random Forest)**: Несмотря на устойчивость данных методов к мультиколлинеарности, для повышения интерпретируемости модели рекомендуется исключить часть коррелирующих признаков (например, оставить **Users** и **Engaged sessions**).
# - Для **методов глубокого обучения (LSTM, GRU, CNN)**: Учитывая способность данных методов выявлять сложные нелинейные зависимости, допустимо использование всех признаков при условии предварительной нормализации данных.
#
#
# #### **2. Умеренная корреляция**
#
# Обнаружена умеренная корреляция между следующими переменными:
# - **Активные сессии на пользователя (Engaged sessions per user)** и **Уровень вовлеченности (Engagement rate)** (\( r = 0.960 \)).
# - **Активные сессии (Engaged sessions)** и **Активные сессии на пользователя (Engaged sessions per user)** (\( r = 0.451 \)).
# - **Активные сессии на пользователя (Engaged sessions per user)** и **Количество событий (Event count)** (\( r = 0.395 \)).
#
# **Рекомендации:**
# - Для **классических методов (VAR, SVAR)**: Данные методы целесообразно применять для анализа взаимосвязей между несколькими временными рядами. Рекомендуется использование **Engaged sessions per user** и **Engagement rate** для изучения причинно-следственных связей.
# - Для **методов машинного обучения (XGBoost, LightGBM)**: Указанные признаки могут быть использованы в качестве ключевых предикторов для прогнозирования уровня вовлеченности.
# - Для **методов глубокого обучения (LSTM, GRU)**: Учитывая способность данных методов учитывать долгосрочные зависимости, рекомендуется включение всех признаков, включая **Engaged sessions per user** и **Engagement rate**.
#
#
# #### **3. Слабая корреляция**
#
# Выявлена слабая корреляция между:
# - **Среднее время вовлеченности на сессию (Average engagement time per session)** и **События на сессию (Events per session)** (\( r = 0.376 \)).
# - **Активные сессии на пользователя (Engaged sessions per user)** и **События на сессию (Events per session)** (\( r = 0.270 \)).
# - **Уровень вовлеченности (Engagement rate)** и **События на сессию (Events per session)** (\( r = 0.309 \)).
#
# **Рекомендации:**
# - Для **классических методов (ARIMA, SARIMAX)**: Указанные признаки могут быть исключены из модели ввиду их слабого влияния на общие метрики.
# - Для **методов машинного обучения (Random Forest)**: Данные признаки могут быть полезны для анализа поведения пользователей на уровне отдельных сессий, однако их вклад в модель будет незначительным.
# - Для **методов глубокого обучения (CNN)**: Учитывая способность данных методов выявлять локальные паттерны, слабые корреляции могут быть полезны для анализа.
#
#
#
# #### **4. Отрицательная корреляция**
#
# Обнаружена слабая отрицательная корреляция между:
# - **Среднее время вовлеченности на сессию (Average engagement time per session)** и **Пользователи (Users)** (\( r = -0.088 \)).
# - **Среднее время вовлеченности на сессию (Average engagement time per session)** и **Сессии (Sessions)** (\( r = -0.095 \)).
# - **Среднее время вовлеченности на сессию (Average engagement time per session)** и **Активные сессии (Engaged sessions)** (\( r = -0.062 \)).
#
# **Рекомендации:**
# - Для **классических методов (SARIMAX)**: Указанные признаки могут быть полезны для учета внешних факторов, таких как изменение поведения пользователей при увеличении трафика.
# - Для **методов машинного обучения (XGBoost, LightGBM)**: Данные признаки могут быть исключены из модели ввиду их минимального влияния.
# - Для **методов глубокого обучения (GRU)**: Учитывая способность данных методов учитывать сложные зависимости, слабая отрицательная корреляция может быть полезна для анализа.
#
#
#
# #### **5. Практически отсутствует корреляция**
#
# Корреляция практически отсутствует между:
# - **Среднее время вовлеченности на сессию (Average engagement time per session)** и **Количество событий (Event count)** (\( r = -0.044 \)).
# - **События на сессию (Events per session)** и **Пользователи (Users)** (\( r = 0.041 \)).
# - **События на сессию (Events per session)** и **Сессии (Sessions)** (\( r = 0.028 \)).
#
# **Рекомендации:**
# - Для всех методов: Указанные признаки могут быть исключены из модели, так как они не несут значимой информации для целевой переменной.
#
#
#
# ### **Рекомендации по выбору признаков для различных методов**
#
# #### **1. Классические методы**
# - **ARIMA**: Рекомендуется использование **Users** или **Sessions** в качестве основного признака. Сильно коррелирующие признаки следует исключить.
# - **SARIMAX**: Целесообразно включение внешних переменных, таких как маркетинговые кампании или сезонные факторы. Для учета уровня вовлеченности рекомендуется использование **Engaged sessions per user** и **Engagement rate**.
# - **VAR/SVAR**: Данные методы подходят для анализа взаимосвязей между несколькими временными рядами, такими как **Users**, **Engaged sessions** и **Event count**.
#
# #### **2. Методы машинного обучения**
# - **XGBoost/LightGBM**: Рекомендуется использование **Users**, **Engaged sessions**, **Engaged sessions per user** и **Engagement rate** в качестве ключевых признаков. Слабо коррелирующие признаки следует исключить.
# - **Random Forest**: Возможно использование всех признаков при условии тщательной настройки гиперпараметров для предотвращения переобучения.
#
# #### **3. Методы глубокого обучения**
# - **LSTM/GRU**: Рекомендуется использование всех признаков, включая **Users**, **Engaged sessions**, **Engaged sessions per user** и **Engagement rate**. Данные должны быть нормализованы для улучшения сходимости модели.
# - **CNN**: Целесообразно использование признаков, которые могут содержать локальные паттерны, таких как **Events per session** и **Average engagement time per session**.
#
#
# Таким образом, анализ корреляционной матрицы позволяет выделить ключевые признаки для различных методов моделирования. Для классических методов важно избегать мультиколлинеарности и использовать минимальное количество признаков. Методы машинного обучения более устойчивы к мультиколлинеарности, но требуют тщательной настройки гиперпараметров. Методы глубокого обучения способны учитывать сложные зависимости, но требуют больших объемов данных и вычислительных ресурсов. Выбор признаков и методов зависит от специфики данных и задач исследования.

# %% [markdown]
# На основе корреляционного анализа и рекомендаций, удалим признаки с низкой корреляцией и избыточные признаки, чтобы упростить модель и избежать мультиколлинеарности. Вот обновленный код с учетом удаления таких признаков:
#
# Код для удаления признаков с низкой корреляцией

# %%
# Удаление признаков с низкой корреляцией и избыточных признаков
columns_to_drop = [
    'Sessions',  # Сильно коррелирует с Users
    'Engaged sessions',  # Сильно коррелирует с Users
    'Average engagement time per session',  # Низкая корреляция
    'Events per session',  # Низкая корреляция
    'Session primary channel group_Email',  # Пример категориального признака с низкой значимостью
    'Session primary channel group_Organic Video',  # Пример категориального признака с низкой значимостью
    'Session primary channel group_Unassigned',  # Пример категориального признака с низкой значимостью
]

# Удаляем признаки
data_cleaned = data.drop(columns=columns_to_drop)

# Проверяем оставшиеся признаки
print(data_cleaned.columns)
# Out:
# Index(['DateTime', 'Users', 'Engaged sessions per user', 'Engagement rate',
#        'Event count', 'Session primary channel group_Organic Search',
#        'Session primary channel group_Organic Social',
#        'Session primary channel group_Referral', 'Hour', 'Day_of_week',
#        'Month'],
#       dtype='object')

# %% [markdown]
# #### **6. Сегментация данных**
#
# Сегментация данных позволяет выделить группы с похожими характеристиками для более детального анализа.
#
# ##### **6.1. Кластеризация**
# Для кластеризации используется метод KMeans.

# %%
from sklearn.cluster import KMeans

# Кластеризация данных
kmeans = KMeans(n_clusters=3, random_state=42)
data['Cluster'] = kmeans.fit_predict(data[numeric_columns])

# Визуализация кластеров
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sessions', y='Event count', hue='Cluster', data=data, palette='viridis')
plt.title('Кластеризация пользователей')
plt.show()

# %% [markdown]
# ####7. **Временные лаги и скользящие окна**
# Для временных рядов можно создать признаки на основе лагов и скользящих окон.

# %%
# Добавляем лаги для Engagement rate
data['Lag1_EngagementRate'] = data['Engagement rate'].shift(1)  # Лаг 1
data['Lag2_EngagementRate'] = data['Engagement rate'].shift(2)  # Лаг 2

# Добавляем скользящее среднее для Engagement rate (окно = 3)
data['RollingMean_EngagementRate'] = data['Engagement rate'].rolling(window=3).mean()

# Выводим первые строки для проверки
print(data[['DateTime', 'Engagement rate', 'Lag1_EngagementRate', 'Lag2_EngagementRate', 'RollingMean_EngagementRate']].head())

# Визуализация временных закономерностей с лагами и скользящим средним
plt.figure(figsize=(14, 8))
plt.plot(data['DateTime'], data['Engagement rate'], label='Engagement Rate', color='blue')
plt.plot(data['DateTime'], data['Lag1_EngagementRate'], label='Lag 1', linestyle='--', color='orange')
plt.plot(data['DateTime'], data['Lag2_EngagementRate'], label='Lag 2', linestyle='--', color='green')
plt.plot(data['DateTime'], data['RollingMean_EngagementRate'], label='Rolling Mean (window=3)', linestyle='-', color='red')
plt.title('Engagement Rate with Lags and Rolling Mean')
plt.xlabel('DateTime')
plt.ylabel('Engagement Rate')
plt.legend()
plt.show()
# Out:
#        DateTime  Engagement rate  Lag1_EngagementRate  Lag2_EngagementRate  \
# 2942 2024-04-06         0.000000                  NaN                  NaN
# 766  2024-04-06         0.606061             0.000000                  NaN
# 2228 2024-04-06         0.487179             0.606061             0.000000
# 637  2024-04-06         0.425926             0.487179             0.606061
# 1329 2024-04-06         0.732143             0.425926             0.487179
#
#       RollingMean_EngagementRate
# 2942                         NaN
# 766                          NaN
# 2228                    0.364413
# 637                     0.506389
# 1329                    0.548416

# %% [markdown]
# ### **Разделение данных на обучающие и тестовые наборы с учетом корреляционного анализа**
#
# На основании проведенного корреляционного анализа и рекомендаций по выбору признаков для различных методов моделирования, процесс разделения данных на обучающие и тестовые наборы был адаптирован для каждой категории моделей. Это позволило оптимизировать процесс обучения и повысить точность прогнозов, минимизируя влияние мультиколлинеарности и учитывая специфику каждого метода.
#
#
# #### **1. Общий подход к разделению данных**
#
# Для всех моделей данные были разделены на обучающую и тестовую выборки с сохранением временного порядка, что исключает возможность утечки информации из будущего в прошлое. Однако выбор признаков варьировался в зависимости от типа модели, что обусловлено их специфическими требованиями к данным.
#
#
# #### **2. Таблица выбора признаков для различных моделей**
#
# В таблице 1 представлены рекомендации по выбору признаков для каждой категории моделей на основе корреляционного анализа.
#
# | **Метод**               | **Рекомендуемые признаки**                                                                 | **Примечания**                                                                 |
# |--------------------------|-------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------|
# | **ARIMA**               | **Users**                                                                                 | Используется один признак для избежания мультиколлинеарности.                  |
# | **SARIMAX**             | **Users**, **Engaged sessions per user**, **Engagement rate**                             | Включаются экзогенные переменные для учета внешних факторов.                   |
# | **XGBoost, LightGBM**   | **Users**, **Engaged sessions**, **Engaged sessions per user**, **Engagement rate**       | Устойчивы к мультиколлинеарности, но требуют тщательного выбора признаков.      |
# | **Random Forest**       | Все признаки                                                                              | Менее чувствительны к мультиколлинеарности, но склонны к переобучению.         |
# | **LSTM, GRU**           | Все признаки                                                                              | Используются все признаки с преобразованием в последовательности.              |
# | **CNN**                 | Все признаки                                                                              | Данные преобразуются в трехмерный тензор для выявления локальных паттернов.    |
#
#
#
# #### **3. Разделение данных для различных моделей**
#
# Ниже приведен код для разделения данных на обучающие и тестовые наборы для каждой категории моделей.
#
# ##### **3.1. Код для разделения данных**

# %%
data.head()
# Out:
#        DateTime  Users  Sessions  Engaged sessions  \
# 2942 2024-04-06      1         1                 0
# 766  2024-04-06     60        66                40
# 2228 2024-04-06     24        39                19
# 637  2024-04-06     65       108                46
# 1329 2024-04-06     47        56                41
#
#       Average engagement time per session  Engaged sessions per user  \
# 2942                             0.000000                   0.000000
# 766                             97.590909                   0.666667
# 2228                            95.256410                   0.791667
# 637                             19.861111                   0.707692
# 1329                            62.642857                   0.872340
#
#       Events per session  Engagement rate  Event count  \
# 2942            2.000000         0.000000          2.0
# 766             4.030303         0.606061        266.0
# 2228            3.871795         0.487179        151.0
# 637             3.898148         0.425926        421.0
# 1329            4.250000         0.732143        238.0
#
#       Session primary channel group_Email  ...  \
# 2942                                False  ...
# 766                                 False  ...
# 2228                                False  ...
# 637                                 False  ...
# 1329                                False  ...
#
#       Session primary channel group_Organic Video  \
# 2942                                        False
# 766                                         False
# 2228                                        False
# 637                                         False
# 1329                                        False
#
#       Session primary channel group_Referral  \
# 2942                                   False
# 766                                    False
# 2228                                    True
# 637                                    False
# 1329                                   False
#
#       Session primary channel group_Unassigned  Hour  Day_of_week  Month  \
# 2942                                      True     0            5      4
# 766                                      False     0            5      4
# 2228                                     False     0            5      4
# 637                                      False     0            5      4
# 1329                                     False     0            5      4
#
#       Cluster  Lag1_EngagementRate  Lag2_EngagementRate  \
# 2942        1                  NaN                  NaN
# 766         0             0.000000                  NaN
# 2228        1             0.606061             0.000000
# 637         2             0.487179             0.606061
# 1329        0             0.425926             0.487179
#
#       RollingMean_EngagementRate
# 2942                         NaN
# 766                          NaN
# 2228                    0.364413
# 637                     0.506389
# 1329                    0.548416
#
# [5 rows x 22 columns]

# %%
# Предположим, что data_cleaned — это ваш DataFrame
# Разделение данных на признаки и целевую переменную
X = data_cleaned.drop(columns=['DateTime', 'Users'])  # Признаки (исключаем целевую переменную и временную метку)
y = data_cleaned['Users']  # Целевая переменная

# Разделение данных на обучающую и тестовую выборки (80:20)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Нормализация данных для моделей, чувствительных к масштабу (LSTM, GRU, CNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Разделение данных для ARIMA
y_train_arima = y_train
y_test_arima = y_test

# Разделение данных для SARIMAX
exog_train_sarimax = X_train[['Engaged sessions per user', 'Engagement rate']]
exog_test_sarimax = X_test[['Engaged sessions per user', 'Engagement rate']]

# Разделение данных для XGBoost и LightGBM
X_train_ml = X_train[['Engaged sessions per user', 'Engagement rate', 'Event count']]  # Без целевой переменной
X_test_ml = X_test[['Engaged sessions per user', 'Engagement rate', 'Event count']]

# Разделение данных для Random Forest
X_train_rf = X_train
X_test_rf = X_test

# Разделение данных для LSTM и GRU
sequence_length = 24  # Длина временного окна (например, 24 часа)
batch_size = 32  # Размер батча

# Преобразуем данные в последовательности для LSTM/GRU
train_generator = TimeseriesGenerator(
    data=X_train_scaled,
    targets=y_train.values,
    length=sequence_length,
    batch_size=batch_size
)

test_generator = TimeseriesGenerator(
    data=X_test_scaled,
    targets=y_test.values,
    length=sequence_length,
    batch_size=batch_size
)

# Удаление избыточных и малозначимых признаков
columns_to_drop = [
    'Session primary channel group_Organic Search',  # Низкая значимость
    'Session primary channel group_Organic Social',  # Низкая значимость
    'Session primary channel group_Referral',  # Низкая значимость
    'Month',  # Низкая значимость
]

# Удаляем признаки
X_train_reduced = X_train.drop(columns=columns_to_drop)
X_test_reduced = X_test.drop(columns=columns_to_drop)

# Нормализация данных для CNN
X_train_reduced_scaled = scaler.fit_transform(X_train_reduced)
X_test_reduced_scaled = scaler.transform(X_test_reduced)

# Разделение данных для CNN
def create_tf_dataset(data, targets, sequence_length, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((data, targets))
    dataset = dataset.window(sequence_length, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda x, y: tf.data.Dataset.zip((x.batch(sequence_length), y.batch(sequence_length))))
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# Создание датасетов для CNN
X_train_cnn = create_tf_dataset(X_train_reduced_scaled, y_train.values, sequence_length, batch_size)
X_test_cnn = create_tf_dataset(X_test_reduced_scaled, y_test.values, sequence_length, batch_size)

# Вывод размеров выборок
print(f"Обучающая выборка для ARIMA: {len(y_train_arima)}, Тестовая выборка для ARIMA: {len(y_test_arima)}")
print(f"Обучающая выборка для SARIMAX: {exog_train_sarimax.shape}, Тестовая выборка для SARIMAX: {exog_test_sarimax.shape}")
print(f"Обучающая выборка для XGBoost/LightGBM: {X_train_ml.shape}, Тестовая выборка: {X_test_ml.shape}")
print(f"Обучающая выборка для Random Forest: {X_train_rf.shape}, Тестовая выборка: {X_test_rf.shape}")
print(f"Обучающая выборка для LSTM/GRU: {len(train_generator)} батчей, Тестовая выборка: {len(test_generator)} батчей")
print(f"Обучающая выборка для CNN: {len(list(X_train_cnn))} батчей, Тестовая выборка: {len(list(X_test_cnn))} батчей")
# Out:
# Обучающая выборка для ARIMA: 2545, Тестовая выборка для ARIMA: 637
# Обучающая выборка для SARIMAX: (2545, 2), Тестовая выборка для SARIMAX: (637, 2)
# Обучающая выборка для XGBoost/LightGBM: (2545, 3), Тестовая выборка: (637, 3)
# Обучающая выборка для Random Forest: (2545, 9), Тестовая выборка: (637, 9)
# Обучающая выборка для LSTM/GRU: 79 батчей, Тестовая выборка: 20 батчей
# Обучающая выборка для CNN: 79 батчей, Тестовая выборка: 20 батчей

# %% [markdown]
# ##ARIMA

# %%
# Нормализация целевой переменной (если необходимо)
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train_arima.values.reshape(-1, 1)).flatten()
y_test_scaled = scaler_y.transform(y_test_arima.values.reshape(-1, 1)).flatten()

# Проверка на стационарность с помощью теста Дики-Фуллера
adf_test = adfuller(y_train_scaled)
print(f"ADF Statistic: {adf_test[0]}")
print(f"p-value: {adf_test[1]}")
if adf_test[1] > 0.05:
    print("Ряд не стационарен. Рекомендуется дифференцирование.")
else:
    print("Ряд стационарен.")

# Графики автокорреляции (ACF) и частичной автокорреляции (PACF)
plot_acf(y_train_scaled, lags=40)
plt.title('График автокорреляции (ACF)')
plt.show()

plot_pacf(y_train_scaled, lags=40)
plt.title('График частичной автокорреляции (PACF)')
plt.show()

# Автоматический подбор параметров ARIMA с помощью auto_arima
auto_model = auto_arima(
    y_train_scaled,
    seasonal=False,  # ARIMA не учитывает сезонность
    trace=True,
    error_action='ignore',
    suppress_warnings=True
)
print(auto_model.summary())

# Обучение модели ARIMA с подобранными параметрами
model = ARIMA(
    endog=y_train_scaled,
    order=auto_model.order
)

results = model.fit(disp=False, maxiter=200)

# Сохранение модели
joblib.dump(results, 'arima_model.pkl')

# Предсказание на тестовой выборке
forecast = results.get_forecast(steps=len(y_test_scaled))
forecast_mean = forecast.predicted_mean

# Денормализация предсказаний
forecast_denorm = scaler_y.inverse_transform(forecast_mean.values.reshape(-1, 1)).flatten()

# Денормализация реальных значений
y_test_denorm = scaler_y.inverse_transform(y_test_scaled.reshape(-1, 1)).flatten()

# Оценка качества модели
mae = mean_absolute_error(y_test_denorm, forecast_denorm)
rmse = np.sqrt(mean_squared_error(y_test_denorm, forecast_denorm))
mape = mean_absolute_percentage_error(y_test_denorm, forecast_denorm)
print(f"MAE на тестовой выборке: {mae}")
print(f"RMSE на тестовой выборке: {rmse}")
print(f"MAPE на тестовой выборке: {mape}")

# Построение графика реальных данных и предсказаний
plt.figure(figsize=(10, 6))
plt.plot(y_test_denorm, label='Реальные данные', color='blue')
plt.plot(forecast_denorm, label='Предсказания', color='red', linestyle='--')
plt.title('Реальные данные vs Предсказания')
plt.xlabel('Время')
plt.ylabel('Users')
plt.legend()
plt.show()

# Анализ остатков
residuals = results.resid  # Остатки модели

# Тест Шапиро-Уилка на нормальность остатков
shapiro_test = shapiro(residuals)
print(f"Shapiro-Wilk test: p-value = {shapiro_test.pvalue}")

# Гистограмма остатков
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=30, edgecolor='black', color='lightblue')
plt.title('Гистограмма остатков')
plt.xlabel('Остатки')
plt.ylabel('Частота')
plt.show()

# График остатков во времени
plt.figure(figsize=(10, 6))
plt.plot(residuals)
plt.title('Остатки модели во времени')
plt.xlabel('Время')
plt.ylabel('Остатки')
plt.show()

# Кросс-валидация на временных рядах
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(y_train_scaled):
    cv_train, cv_test = y_train_scaled[train_index], y_train_scaled[test_index]

    # Обучение модели на cv_train
    cv_model = ARIMA(
        endog=cv_train,
        order=auto_model.order
    )
    cv_results = cv_model.fit(disp=False)

    # Прогнозирование на cv_test
    cv_forecast = cv_results.get_forecast(steps=len(cv_test))
    cv_forecast_mean = cv_forecast.predicted_mean

    # Оценка качества на cv_test
    cv_mae = mean_absolute_error(cv_test, cv_forecast_mean)
    print(f"MAE на кросс-валидации: {cv_mae}")

# Прогнозирование на будущее (пример)
future_steps = 30  # Количество шагов для прогноза
future_forecast = results.get_forecast(steps=future_steps)
future_forecast_mean = future_forecast.predicted_mean

# Денормализация прогноза
future_forecast_denorm = scaler_y.inverse_transform(future_forecast_mean.values.reshape(-1, 1)).flatten()

# График прогноза на будущее
plt.figure(figsize=(10, 6))
plt.plot(future_forecast_denorm, label='Прогноз на будущее', color='green', linestyle='--')
plt.title('Прогноз на будущее')
plt.xlabel('Время')
plt.ylabel('Users')
plt.legend()
plt.show()

# %% [markdown]
# ##SARIMAX

# %%
# Нормализация целевой переменной (если необходимо)
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).flatten()
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).flatten()

# Проверка на стационарность с помощью теста Дики-Фуллера
adf_test = adfuller(y_train_scaled)
print(f"ADF Statistic: {adf_test[0]}")
print(f"p-value: {adf_test[1]}")
if adf_test[1] > 0.05:
    print("Ряд не стационарен. Рекомендуется дифференцирование.")
else:
    print("Ряд стационарен.")

# Графики автокорреляции (ACF) и частичной автокорреляции (PACF)
plot_acf(y_train_scaled, lags=40)
plt.title('График автокорреляции (ACF)')
plt.show()

plot_pacf(y_train_scaled, lags=40)
plt.title('График частичной автокорреляции (PACF)')
plt.show()

# Автоматический подбор параметров SARIMAX с помощью auto_arima
auto_model = auto_arima(
    y_train_scaled,
    exogenous=exog_train_sarimax,
    seasonal=True,
    m=7,
    d=1,
    trace=True,
    error_action='ignore',
    suppress_warnings=True
)
print(auto_model.summary())

# Обучение модели SARIMAX с подобранными параметрами
model = SARIMAX(
    endog=y_train_scaled,
    exog=exog_train_sarimax,
    order=auto_model.order,
    seasonal_order=auto_model.seasonal_order,
    initialization='approximate_diffuse'  # Альтернативный метод инициализации
)

results = model.fit(disp=False, maxiter=200)

# Сохранение модели
joblib.dump(results, 'sarimax_model.pkl')

# Предсказание на тестовой выборке
forecast = results.get_forecast(steps=len(exog_test_sarimax), exog=exog_test_sarimax)
forecast_mean = forecast.predicted_mean

# Денормализация предсказаний
forecast_denorm = scaler_y.inverse_transform(forecast_mean.values.reshape(-1, 1)).flatten()

# Денормализация реальных значений
y_test_denorm = scaler_y.inverse_transform(y_test_scaled.reshape(-1, 1)).flatten()

# Оценка качества модели
mae = mean_absolute_error(y_test_denorm, forecast_denorm)
rmse = np.sqrt(mean_squared_error(y_test_denorm, forecast_denorm))
mape = mean_absolute_percentage_error(y_test_denorm, forecast_denorm)
print(f"MAE на тестовой выборке: {mae}")
print(f"RMSE на тестовой выборке: {rmse}")
print(f"MAPE на тестовой выборке: {mape}")

# Построение графика реальных данных и предсказаний
plt.figure(figsize=(10, 6))
plt.plot(y_test_denorm, label='Реальные данные', color='blue')
plt.plot(forecast_denorm, label='Предсказания', color='red', linestyle='--')
plt.title('Реальные данные vs Предсказания')
plt.xlabel('Время')
plt.ylabel('Users')
plt.legend()
plt.show()

# Анализ остатков
residuals = results.resid  # Остатки модели

# Тест Шапиро-Уилка на нормальность остатков
shapiro_test = shapiro(residuals)
print(f"Shapiro-Wilk test: p-value = {shapiro_test.pvalue}")

# Гистограмма остатков
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=30, edgecolor='black', color='lightblue')
plt.title('Гистограмма остатков')
plt.xlabel('Остатки')
plt.ylabel('Частота')
plt.show()

# График остатков во времени
plt.figure(figsize=(10, 6))
plt.plot(residuals)
plt.title('Остатки модели во времени')
plt.xlabel('Время')
plt.ylabel('Остатки')
plt.show()

# Кросс-валидация на временных рядах
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(y_train_scaled):
    cv_train, cv_test = y_train_scaled[train_index], y_train_scaled[test_index]
    cv_train_X, cv_test_X = exog_train_sarimax.iloc[train_index], exog_train_sarimax.iloc[test_index]

    # Обучение модели на cv_train
    cv_model = SARIMAX(
        endog=cv_train,
        exog=cv_train_X,
        order=auto_model.order,
        seasonal_order=auto_model.seasonal_order
    )
    cv_results = cv_model.fit(disp=False)

    # Прогнозирование на cv_test
    cv_forecast = cv_results.get_forecast(steps=len(cv_test_X), exog=cv_test_X)
    cv_forecast_mean = cv_forecast.predicted_mean

    # Оценка качества на cv_test
    cv_mae = mean_absolute_error(cv_test, cv_forecast_mean)
    print(f"MAE на кросс-валидации: {cv_mae}")

# Прогнозирование на будущее (пример)
future_steps = 30  # Количество шагов для прогноза
future_exog = exog_test_sarimax.iloc[:future_steps]  # Используем последние данные для прогноза
future_forecast = results.get_forecast(steps=future_steps, exog=future_exog)
future_forecast_mean = future_forecast.predicted_mean

# Денормализация прогноза
future_forecast_denorm = scaler_y.inverse_transform(future_forecast_mean.values.reshape(-1, 1)).flatten()

# График прогноза на будущее
plt.figure(figsize=(10, 6))
plt.plot(future_forecast_denorm, label='Прогноз на будущее', color='green', linestyle='--')
plt.title('Прогноз на будущее')
plt.xlabel('Время')
plt.ylabel('Users')
plt.legend()
plt.show()
# Out:
# ADF Statistic: -9.566234296205627
# p-value: 2.3530690685703674e-16
# Ряд стационарен.
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=6877.899, Time=35.28 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=8585.145, Time=0.09 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=7879.348, Time=0.81 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=6946.751, Time=1.79 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=8583.146, Time=0.10 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=6876.119, Time=13.48 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=6874.157, Time=3.82 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=6876.119, Time=11.60 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,2)(0,0,0)[7] intercept   : AIC=6954.220, Time=1.02 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,1)(0,0,0)[7] intercept   : AIC=6913.798, Time=1.30 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(3,1,2)(0,0,0)[7] intercept   : AIC=6875.949, Time=9.73 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,3)(0,0,0)[7] intercept   : AIC=6877.065, Time=6.65 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(0,0,0)[7] intercept   : AIC=6939.819, Time=0.93 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,3)(0,0,0)[7] intercept   : AIC=6874.047, Time=7.25 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,3)(1,0,0)[7] intercept   : AIC=6876.064, Time=9.96 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,3)(0,0,1)[7] intercept   : AIC=6876.003, Time=12.77 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,3)(1,0,1)[7] intercept   : AIC=6880.176, Time=15.90 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,3)(0,0,0)[7] intercept   : AIC=6897.918, Time=3.99 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,4)(0,0,0)[7] intercept   : AIC=6875.971, Time=8.55 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,2)(0,0,0)[7] intercept   : AIC=6935.623, Time=2.43 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,4)(0,0,0)[7] intercept   : AIC=6883.122, Time=2.29 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,4)(0,0,0)[7] intercept   : AIC=6878.042, Time=4.59 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,3)(0,0,0)[7]             : AIC=6872.048, Time=2.49 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,3)(1,0,0)[7]             : AIC=6874.002, Time=5.28 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,3)(0,0,1)[7]             : AIC=6874.003, Time=2.43 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,3)(1,0,1)[7]             : AIC=6876.003, Time=3.17 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,3)(0,0,0)[7]             : AIC=6895.918, Time=1.07 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,2)(0,0,0)[7]             : AIC=6874.374, Time=1.55 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,3)(0,0,0)[7]             : AIC=6873.989, Time=4.64 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,4)(0,0,0)[7]             : AIC=6873.971, Time=3.49 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,2)(0,0,0)[7]             : AIC=6933.623, Time=0.56 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,4)(0,0,0)[7]             : AIC=6881.123, Time=0.70 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,2)(0,0,0)[7]             : AIC=6872.157, Time=1.57 sec
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,4)(0,0,0)[7]             : AIC=6876.041, Time=1.51 sec
#
# Best model:  ARIMA(1,1,3)(0,0,0)[7]
# Total fit time: 182.918 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2545
# Model:               SARIMAX(1, 1, 3)   Log Likelihood               -3431.024
# Date:                Mon, 06 Jan 2025   AIC                           6872.048
# Time:                        16:13:42   BIC                           6901.255
# Sample:                             0   HQIC                          6882.642
#                                - 2545
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6378      0.061     10.464      0.000       0.518       0.757
# ma.L1         -1.6186      0.062    -25.909      0.000      -1.741      -1.496
# ma.L2          0.6210      0.075      8.259      0.000       0.474       0.768
# ma.L3          0.0580      0.024      2.444      0.015       0.011       0.105
# sigma2         0.8683      0.019     45.983      0.000       0.831       0.905
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               334.71
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.21   Skew:                             0.14
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# MAE на тестовой выборке: 21.975698897017853
# RMSE на тестовой выборке: 28.87829942234992
# MAPE на тестовой выборке: 332160512590834.3
# Shapiro-Wilk test: p-value = 7.221722316528246e-28
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# MAE на кросс-валидации: 0.7747111887063636
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# MAE на кросс-валидации: 0.7690464518521863
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# MAE на кросс-валидации: 0.9042352708142433
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# MAE на кросс-валидации: 0.6926902713185351
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# MAE на кросс-валидации: 0.7262038720601838

# %% [markdown]
# На основании проведенного анализа временного ряда с использованием модели SARIMAX можно сделать следующие выводы:
#
# ### 1. **Анализ стационарности**
# Результаты теста Дики-Фуллера (ADF) свидетельствуют о стационарности временного ряда:
# - ADF Statistic: -9.566
# - p-value: 2.35e-16 (p < 0.05)
#
# Таким образом, гипотеза о нестационарности ряда отвергается, что исключает необходимость дополнительного дифференцирования.
#
# ### 2. **Сезонная компонента**
# Несмотря на указание параметра сезонности `m=7` (предполагающего наличие недельной сезонности), модель SARIMAX, подобранная с использованием алгоритма `auto_arima`, не выявила значимой сезонной составляющей. Оптимальная модель имеет параметры **SARIMAX(1,1,3)(0,0,0)[7]**, где сезонные компоненты (`P`, `D`, `Q`) равны нулю. Это может указывать на отсутствие выраженной сезонности в данных или на недостаточную значимость сезонных колебаний для их учета в модели.
#
# ### 3. **Качество модели**
# Модель SARIMAX(1,1,3)(0,0,0)[7] демонстрирует следующие характеристики:
# - **AIC (Akaike Information Criterion)**: 6872.048
# - **BIC (Bayesian Information Criterion)**: 6901.255
# - **Логарифмическая функция правдоподобия (Log Likelihood)**: -3431.024
#
# На тестовой выборке получены следующие метрики:
# - **MAE (Mean Absolute Error)**: 21.98
# - **RMSE (Root Mean Squared Error)**: 28.88
# - **MAPE (Mean Absolute Percentage Error)**: 3.32e+14
#
# Аномально высокое значение MAPE может быть связано с наличием значений, близких к нулю, в целевой переменной, что делает данную метрику неустойчивой. Рекомендуется рассмотреть альтернативные метрики, такие как SMAPE или WMAPE, для более корректной оценки точности модели.
#
# ### 4. **Анализ остатков**
# Результаты теста Шапиро-Уилка на нормальность распределения остатков:
# - p-value: 7.22e-28
#
# Низкое значение p-value свидетельствует о значительном отклонении распределения остатков от нормального. Это может быть обусловлено наличием выбросов, неучтенных паттернов или нелинейных зависимостей в данных. Для дальнейшего анализа рекомендуется визуализировать остатки и провести их детальное исследование.
#
#
# ### 5. **Кросс-валидация**
# Результаты кросс-валидации на временных рядах (TimeSeriesSplit) показали стабильность модели:
# - MAE на кросс-валидации варьируется в диапазоне от 0.69 до 0.90, что подтверждает устойчивость модели к различным подвыборкам данных.
#
# ### 6. **Прогнозирование**
# Модель успешно спрогнозировала значения на тестовой выборке, однако высокое значение MAPE требует дополнительного анализа. Возможные причины включают:
# - Наличие выбросов или аномалий в данных.
# - Недостаточное качество масштабирования целевой переменной.
# - Неучтенные внешние факторы, влияющие на целевую переменную.
#
#
# Таким образом, проведенный анализ показал, что временной ряд является стационарным, а модель SARIMAX(1,1,3)(0,0,0)[7] демонстрирует удовлетворительную производительность. Однако отсутствие значимой сезонной компоненты и аномально высокое значение MAPE указывают на необходимость дальнейшего исследования данных и улучшения модели. Рекомендуется провести дополнительные эксперименты с учетом указанных рекомендаций для повышения точности прогнозирования.

# %% [markdown]
# Перепишем для SARIMAX(1,1,3)(0,0,7)[7]:

# %%
# Нормализация целевой переменной (если необходимо)
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).flatten()
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).flatten()

# Проверка на стационарность с помощью теста Дики-Фуллера
adf_test = adfuller(y_train_scaled)
print(f"ADF Statistic: {adf_test[0]}")
print(f"p-value: {adf_test[1]}")
if adf_test[1] > 0.05:
    print("Ряд не стационарен. Рекомендуется дифференцирование.")
else:
    print("Ряд стационарен.")

# Графики автокорреляции (ACF) и частичной автокорреляции (PACF)
plot_acf(y_train_scaled, lags=40)
plt.title('График автокорреляции (ACF)')
plt.show()

plot_pacf(y_train_scaled, lags=40)
plt.title('График частичной автокорреляции (PACF)')
plt.show()

# Обучение модели SARIMAX с заданными параметрами
model = SARIMAX(
    endog=y_train_scaled,
    exog=exog_train_sarimax,
    order=(1, 1, 3),  # Задаем параметры (p, d, q)
    seasonal_order=(0, 0, 7, 7),  # Задаем сезонные параметры (P, D, Q, m)
    initialization='approximate_diffuse'  # Альтернативный метод инициализации
)

results = model.fit(disp=False, maxiter=200)

# Сохранение модели
joblib.dump(results, 'sarimax_model.pkl')

# Предсказание на тестовой выборке
forecast = results.get_forecast(steps=len(exog_test_sarimax), exog=exog_test_sarimax)
forecast_mean = forecast.predicted_mean

# Денормализация предсказаний
forecast_denorm = scaler_y.inverse_transform(forecast_mean.values.reshape(-1, 1)).flatten()

# Денормализация реальных значений
y_test_denorm = scaler_y.inverse_transform(y_test_scaled.reshape(-1, 1)).flatten()

# Оценка качества модели
mae = mean_absolute_error(y_test_denorm, forecast_denorm)
rmse = np.sqrt(mean_squared_error(y_test_denorm, forecast_denorm))
mape = mean_absolute_percentage_error(y_test_denorm, forecast_denorm)
print(f"MAE на тестовой выборке: {mae}")
print(f"RMSE на тестовой выборке: {rmse}")
print(f"MAPE на тестовой выборке: {mape}")

# Построение графика реальных данных и предсказаний
plt.figure(figsize=(10, 6))
plt.plot(y_test_denorm, label='Реальные данные', color='blue')
plt.plot(forecast_denorm, label='Предсказания', color='red', linestyle='--')
plt.title('Реальные данные vs Предсказания')
plt.xlabel('Время')
plt.ylabel('Users')
plt.legend()
plt.show()

# Анализ остатков
residuals = results.resid  # Остатки модели

# Тест Шапиро-Уилка на нормальность остатков
shapiro_test = shapiro(residuals)
print(f"Shapiro-Wilk test: p-value = {shapiro_test.pvalue}")

# Гистограмма остатков
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=30, edgecolor='black', color='lightblue')
plt.title('Гистограмма остатков')
plt.xlabel('Остатки')
plt.ylabel('Частота')
plt.show()

# График остатков во времени
plt.figure(figsize=(10, 6))
plt.plot(residuals)
plt.title('Остатки модели во времени')
plt.xlabel('Время')
plt.ylabel('Остатки')
plt.show()

# Кросс-валидация на временных рядах
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(y_train_scaled):
    cv_train, cv_test = y_train_scaled[train_index], y_train_scaled[test_index]
    cv_train_X, cv_test_X = exog_train_sarimax.iloc[train_index], exog_train_sarimax.iloc[test_index]

    # Обучение модели на cv_train
    cv_model = SARIMAX(
        endog=cv_train,
        exog=cv_train_X,
        order=(1, 1, 3),  # Задаем параметры (p, d, q)
        seasonal_order=(0, 0, 7, 7)  # Задаем сезонные параметры (P, D, Q, m)
    )
    cv_results = cv_model.fit(disp=False)

    # Прогнозирование на cv_test
    cv_forecast = cv_results.get_forecast(steps=len(cv_test_X), exog=cv_test_X)
    cv_forecast_mean = cv_forecast.predicted_mean

    # Оценка качества на cv_test
    cv_mae = mean_absolute_error(cv_test, cv_forecast_mean)
    print(f"MAE на кросс-валидации: {cv_mae}")

# Прогнозирование на будущее (пример)
future_steps = 30  # Количество шагов для прогноза
future_exog = exog_test_sarimax.iloc[:future_steps]  # Используем последние данные для прогноза
future_forecast = results.get_forecast(steps=future_steps, exog=future_exog)
future_forecast_mean = future_forecast.predicted_mean

# Денормализация прогноза
future_forecast_denorm = scaler_y.inverse_transform(future_forecast_mean.values.reshape(-1, 1)).flatten()

# График прогноза на будущее
plt.figure(figsize=(10, 6))
plt.plot(future_forecast_denorm, label='Прогноз на будущее', color='green', linestyle='--')
plt.title('Прогноз на будущее')
plt.xlabel('Время')
plt.ylabel('Users')
plt.legend()
plt.show()
# Out:
# ADF Statistic: -9.566234296205627
# p-value: 2.3530690685703674e-16
# Ряд стационарен.
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# MAE на тестовой выборке: 22.068154864655856
# RMSE на тестовой выборке: 29.099771588314038
# MAPE на тестовой выборке: 305169759332246.1
# Shapiro-Wilk test: p-value = 1.1288488918983459e-27
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# MAE на кросс-валидации: 0.7675363568880756
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# MAE на кросс-валидации: 0.7657887953916398
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# MAE на кросс-валидации: 0.8951633903751632
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# MAE на кросс-валидации: 0.682469503841019

# %% [markdown]
# #### **Литература**
#
# 1. Vlahogianni, E. I., Karlaftis, M. G., & Golias, J. C. Short-term traffic forecasting: Where we are and where we’re going / E. I. Vlahogianni, M. G. Karlaftis, J. C. Golias // Transportation Research Part C: Emerging Technologies. – 2014. – Vol. 43. – P. 3–19. – DOI: 10.1016/j.trc.2014.01.005.
# 2. Чучуева, И. А. Модель прогнозирования временных рядов по выборке максимального подобия : специальность 05.13.18 "Математическое моделирование, численные методы и комплексы программ" : диссертация на соискание ученой степени кандидата технических наук / Чучуева Ирина Александровна. – Москва, 2012. – 154 с. – EDN QFTSCJ.
# 3. Chen, T., & Guestrin, C. XGBoost: A Scalable Tree Boosting System / T. Chen, C. Guestrin // Proceedings of the 22nd ACM SIGKDD International Conference on Knowledge Discovery and Data Mining. – 2016. – P. 785–794. – DOI: 10.1145/2939672.2939785.
# 4. Hochreiter, S., & Schmidhuber, J. Long Short-Term Memory / S. Hochreiter, J. Schmidhuber // Neural Computation. – 1997. – Vol. 9. – P. 1735–1780. – DOI: 10.1162/neco.1997.9.8.1735.
# 5. Zhang, G., Eddy Patuwo, B., & Hu, M. Y. Forecasting with artificial neural networks: The state of the art / G. Zhang, B. Eddy Patuwo, M. Y. Hu // International Journal of Forecasting. – 1998. – Vol. 14. – P. 35–62. – DOI: 10.1016/S0169-2070(97)00044-7.
# 6. Smyl, S. A hybrid method of exponential smoothing and recurrent neural networks for time series forecasting / S. Smyl // International Journal of Forecasting. – 2020. – Vol. 36. – P. 75–85. – DOI: 10.1016/j.ijforecast.2019.03.017.
