# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ABC_DataMining/blob/main/Python/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BF%D0%BE_%D0%9E%D0%9E%D0%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Вариант 1. Учет и управление сотрудниками в компании
#
# Разработайте программное обеспечение для учета и управления сотрудниками в компании. Программа должна предоставлять возможность создания записей о сотрудниках, учета их должностей, зарплат, отделов и других данных. Также программа должна поддерживать выполнение различных операций с данными сотрудников, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Employee` (сотрудник)**
#    - Создайте абстрактный класс `Employee`, который будет являться базовым для всех типов сотрудников.
#    - В классе определите:
#      - Абстрактный метод `calculate_bonus`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех сотрудников: `name` (имя), `surname` (фамилия), `age` (возраст), `position` (должность), `department` (отдел), `salary` (зарплата).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Имя Фамилия, Должность, Отдел").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения сотрудников по зарплате или возрасту.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов сотрудников:
#      - `Manager` (менеджер): добавьте атрибут `team_size` (количество подчиненных).
#      - `Developer` (разработчик): добавьте атрибут `programming_languages` (список языков программирования).
#      - `Intern` (стажер): добавьте атрибут `internship_duration` (продолжительность стажировки).
#    - В каждом подклассе переопределите метод `calculate_bonus` для расчета бонуса в зависимости от типа сотрудника.
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Менеджер: Имя Фамилия, Количество подчиненных: X").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Department`, который будет содержать список сотрудников и методы для управления ими:
#      - `add_employee`: добавить сотрудника в отдел.
#      - `remove_employee`: удалить сотрудника из отдела.
#      - `get_employees`: получить список всех сотрудников отдела.
#      - `get_top_employees`: получить топ-N сотрудников отдела по зарплате.
#    - Используйте **композицию**: добавьте атрибут `address` (адрес отдела) через отдельный класс `Address`.
#    - Используйте **агрегацию**: отдел может существовать без сотрудников, но сотрудники могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сотрудниками**
#    - Создайте интерфейс `Workable`, который определяет метод `work`. Этот метод должен быть реализован в каждом подклассе и описывать действия сотрудника на рабочем месте:
#      - Для менеджера: "Управляю командой".
#      - Для разработчика: "Пишу код".
#      - Для стажера: "Обучаюсь".
#    - Добавьте второй интерфейс `Notifiable`, который определяет метод `notify`. Этот метод должен быть реализован для отправки уведомлений сотрудникам (например, о повышении зарплаты или переводе в другой отдел).
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий сотрудников. Например, метод `log_action`, который записывает действия сотрудника (например, "Сотрудник [Имя] выполнил действие").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Вам предоставлено повышение!" или "Вы переведены в новый отдел").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `EmployeeMeta`, который автоматически регистрирует все подклассы `Employee` в реестре. Это позволит динамически создавать экземпляры сотрудников по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `EmployeeFactory` с методом `create_employee`, который принимает тип сотрудника (например, `"manager"`, `"developer"`, `"intern"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания сотрудников в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на повышение зарплаты. Например:
#      - Руководитель отдела может одобрить повышение до 500 единиц.
#      - HR-отдел может одобрить повышение до 1000 единиц.
#      - Директор может одобрить любое повышение.
#    - Создайте цепочку обработчиков (`DepartmentHead`, `HRDepartment`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса расчета бонусов. Создайте базовый класс `BonusCalculator` с методом `calculate_bonus`, который определяет общую структуру расчета:
#      - Получение базового бонуса.
#      - Получение дополнительного бонуса.
#      - Применение бонуса.
#    - Подклассы (`ManagerBonusCalculator`, `DeveloperBonusCalculator`) должны реализовывать конкретные шаги расчета.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, изменение данных сотрудника или расчет бонуса). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidAgeError`: если возраст сотрудника меньше 18 лет.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `DepartmentNotFoundError`: если отдел не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о сотрудниках в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения сотрудников по зарплате, возрасту или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание сотрудников:
#    - Используйте `EmployeeFactory` для создания сотрудников разных типов.
#    - Добавьте сотрудников в отдел с помощью метода `add_employee` класса `Department`.
#
# 2. Управление данными:
#    - Редактируйте данные сотрудников через сеттеры.
#    - Удаляйте сотрудников из отдела с помощью метода `remove_employee`.
#
# 3. Анализ данных:
#    - Получите список всех сотрудников отдела с помощью метода `get_employees`.
#    - Найдите топ-N сотрудников по зарплате с помощью метода `get_top_employees`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке создания сотрудника с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 2. Учет и управление проектами в компании
#
# Разработайте программное обеспечение для учета и управления проектами в компании. Программа должна предоставлять возможность создания записей о проектах, учета их статусов, сроков выполнения, бюджета, участников и других данных. Также программа должна поддерживать выполнение различных операций с данными проектов, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Project` (проект)**
#    - Создайте абстрактный класс `Project`, который будет являться базовым для всех типов проектов.
#    - В классе определите:
#      - Абстрактный метод `calculate_progress`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех проектов: `name` (название), `start_date` (дата начала), `end_date` (дата окончания), `budget` (бюджет), `status` (статус), `team` (список участников).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Название проекта: [название], Статус: [статус]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения проектов по бюджету или сроку выполнения.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов проектов:
#      - `SoftwareProject` (программный проект): добавьте атрибут `programming_languages` (список языков программирования).
#      - `MarketingProject` (маркетинговый проект): добавьте атрибут `target_audience` (целевая аудитория).
#      - `ResearchProject` (исследовательский проект): добавьте атрибут `research_field` (область исследований).
#    - В каждом подклассе переопределите метод `calculate_progress` для расчета прогресса в зависимости от типа проекта.
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Программный проект: [название], Языки: [список языков]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Team`, который будет содержать список участников проекта и методы для управления ими:
#      - `add_member`: добавить участника в команду.
#      - `remove_member`: удалить участника из команды.
#      - `get_members`: получить список всех участников команды.
#      - `get_team_size`: получить количество участников команды.
#    - Используйте **композицию**: добавьте атрибут `leader` (руководитель проекта) через отдельный класс `Employee`.
#    - Используйте **агрегацию**: команда может существовать без участников, но участники могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с проектами**
#    - Создайте интерфейс `Trackable`, который определяет метод `track_progress`. Этот метод должен быть реализован в каждом подклассе и описывать текущий прогресс проекта:
#      - Для программного проекта: "Прогресс: X% завершено".
#      - Для маркетингового проекта: "Охват аудитории: Y человек".
#      - Для исследовательского проекта: "Опубликовано Z статей".
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о проекте (например, "Отчет по проекту [название]: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с проектами. Например, метод `log_action`, который записывает действия (например, "Проект [название] обновлен: [действие]").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Проект [название] завершен!" или "Проект [название] требует внимания").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `ProjectMeta`, который автоматически регистрирует все подклассы `Project` в реестре. Это позволит динамически создавать экземпляры проектов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `ProjectFactory` с методом `create_project`, который принимает тип проекта (например, `"software"`, `"marketing"`, `"research"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания проектов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение бюджета проекта. Например:
#      - Руководитель проекта может одобрить изменение бюджета до 1000 единиц.
#      - Финансовый отдел может одобрить изменение бюджета до 5000 единиц.
#      - Директор может одобрить любое изменение бюджета.
#    - Создайте цепочку обработчиков (`ProjectLeader`, `FinanceDepartment`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса расчета прогресса проекта. Создайте базовый класс `ProgressCalculator` с методом `calculate_progress`, который определяет общую структуру расчета:
#      - Получение текущего состояния проекта.
#      - Расчет прогресса на основе состояния.
#      - Возврат результата.
#    - Подклассы (`SoftwareProgressCalculator`, `MarketingProgressCalculator`) должны реализовывать конкретные шаги расчета.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, изменение данных проекта или генерация отчета). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidDateError`: если дата окончания проекта раньше даты начала.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `ProjectNotFoundError`: если проект не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о проектах в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения проектов по бюджету, сроку выполнения или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание проектов:
#    - Используйте `ProjectFactory` для создания проектов разных типов.
#    - Добавьте участников в команду проекта с помощью метода `add_member` класса `Team`.
#
# 2. Управление данными:
#    - Редактируйте данные проектов через сеттеры.
#    - Удаляйте участников из команды с помощью метода `remove_member`.
#
# 3. Анализ данных:
#    - Получите список всех участников проекта с помощью метода `get_members`.
#    - Отслеживайте прогресс проекта с помощью метода `track_progress`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке создания проекта с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 3. Учет и управление учебными курсами в образовательной платформе
#
# Разработайте программное обеспечение для учета и управления учебными курсами на образовательной платформе. Программа должна предоставлять возможность создания записей о курсах, учета их тематик, преподавателей, студентов и других данных. Также программа должна поддерживать выполнение различных операций с данными курсов, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Course` (курс)**
#    - Создайте абстрактный класс `Course`, который будет являться базовым для всех типов курсов.
#    - В классе определите:
#      - Абстрактный метод `calculate_completion_rate`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех курсов: `title` (название), `start_date` (дата начала), `end_date` (дата окончания), `instructor` (преподаватель), `students` (список студентов), `topics` (список тем).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Курс: Название, Преподаватель: Имя Фамилия").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения курсов по количеству студентов или продолжительности.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов курсов:
#      - `ProgrammingCourse` (курс программирования): добавьте атрибут `languages` (языки программирования).
#      - `DesignCourse` (курс дизайна): добавьте атрибут `tools` (используемые инструменты).
#      - `ScienceCourse` (курс наук): добавьте атрибут `field` (область науки).
#    - В каждом подклассе переопределите метод `calculate_completion_rate` для расчета процента завершения курса в зависимости от типа курса.
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Курс программирования: Название, Языки: Python, JavaScript").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Platform`, который будет содержать список курсов и методы для управления ими:
#      - `add_course`: добавить курс на платформу.
#      - `remove_course`: удалить курс с платформы.
#      - `get_courses`: получить список всех курсов платформы.
#      - `get_top_courses`: получить топ-N курсов платформы по количеству студентов.
#    - Используйте **композицию**: добавьте атрибут `address` (адрес платформы) через отдельный класс `Address`.
#    - Используйте **агрегацию**: платформа может существовать без курсов, но курсы могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с курсами**
#    - Создайте интерфейс `Teachable`, который определяет метод `teach`. Этот метод должен быть реализован в каждом подклассе и описывать процесс обучения:
#      - Для курса программирования: "Провожу лекции по алгоритмам".
#      - Для курса дизайна: "Объясняю принципы композиции".
#      - Для курса наук: "Провожу лабораторные работы".
#    - Добавьте второй интерфейс `Assessable`, который определяет метод `assess_progress`. Этот метод должен быть реализован для оценки прогресса студентов на курсе.
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий курсов. Например, метод `log_action`, который записывает действия курса (например, "Курс [Название] начался").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений студентам. Например, метод `notify_students`, который отправляет уведомления (например, "Новый модуль доступен" или "Курс завершен").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `CourseMeta`, который автоматически регистрирует все подклассы `Course` в реестре. Это позволит динамически создавать экземпляры курсов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `CourseFactory` с методом `create_course`, который принимает тип курса (например, `"programming"`, `"design"`, `"science"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания курсов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение программы курса. Например:
#      - Преподаватель может одобрить изменения в материалах.
#      - Методический отдел может одобрить изменения в структуре курса.
#      - Руководство платформы может одобрить любые изменения.
#    - Создайте цепочку обработчиков (`InstructorHandler`, `MethodologyDepartmentHandler`, `ManagementHandler`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса оценки прогресса студентов. Создайте базовый класс `ProgressAssessor` с методом `assess_progress`, который определяет общую структуру оценки:
#      - Получение текущих результатов студентов.
#      - Вычисление среднего балла.
#      - Применение оценки.
#    - Подклассы (`ProgrammingProgressAssessor`, `DesignProgressAssessor`) должны реализовывать конкретные шаги оценки.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, изменение программы курса или оценка прогресса). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidDateError`: если дата окончания курса раньше даты начала.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `CourseNotFoundError`: если курс не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о курсах в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения курсов по количеству студентов, продолжительности или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание курсов:
#    - Используйте `CourseFactory` для создания курсов разных типов.
#    - Добавьте курсы на платформу с помощью метода `add_course` класса `Platform`.
#
# 2. Управление данными:
#    - Редактируйте данные курсов через сеттеры.
#    - Удаляйте курсы с платформы с помощью метода `remove_course`.
#
# 3. Анализ данных:
#    - Получите список всех курсов платформы с помощью метода `get_courses`.
#    - Найдите топ-N курсов по количеству студентов с помощью метода `get_top_courses`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке создания курса с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 4. Учет и управление заказами в интернет-магазине
#
# Разработайте программное обеспечение для учета и управления заказами в интернет-магазине. Программа должна предоставлять возможность создания записей о заказах, учета их статусов, клиентов, товаров, стоимости и других данных. Также программа должна поддерживать выполнение различных операций с заказами, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Order` (заказ)**
#    - Создайте абстрактный класс `Order`, который будет являться базовым для всех типов заказов.
#    - В классе определите:
#      - Абстрактный метод `calculate_total`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех заказов: `order_id` (идентификатор заказа), `customer` (клиент), `order_date` (дата заказа), `status` (статус заказа), `items` (список товаров).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Заказ №[order_id], Статус: [статус]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения заказов по стоимости или дате.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов заказов:
#      - `OnlineOrder` (онлайн-заказ): добавьте атрибут `payment_method` (способ оплаты).
#      - `PhoneOrder` (заказ по телефону): добавьте атрибут `operator_name` (имя оператора).
#      - `StoreOrder` (заказ в магазине): добавьте атрибут `store_location` (местоположение магазина).
#    - В каждом подклассе переопределите метод `calculate_total` для расчета общей стоимости заказа с учетом скидок или дополнительных сборов.
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Онлайн-заказ №[order_id], Способ оплаты: [payment_method]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Customer`, который будет содержать информацию о клиенте:
#      - Атрибуты: `name` (имя), `email` (электронная почта), `phone` (телефон), `address` (адрес).
#      - Методы: `place_order` (создать заказ), `get_order_history` (получить историю заказов).
#    - Используйте **композицию**: добавьте атрибут `shipping_address` (адрес доставки) через отдельный класс `Address`.
#    - Используйте **агрегацию**: клиент может существовать без заказов, но заказы могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с заказами**
#    - Создайте интерфейс `Trackable`, который определяет метод `track_status`. Этот метод должен быть реализован в каждом подклассе и описывать текущий статус заказа:
#      - Для онлайн-заказа: "Статус: [статус], Ожидаемая дата доставки: [дата]".
#      - Для заказа по телефону: "Статус: [статус], Оператор: [имя оператора]".
#      - Для заказа в магазине: "Статус: [статус], Магазин: [местоположение]".
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_invoice`. Этот метод должен быть реализован для генерации счета на оплату (например, "Счет для заказа №[order_id]: [стоимость]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с заказами. Например, метод `log_action`, который записывает действия (например, "Заказ №[order_id] обновлен: [действие]").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Заказ №[order_id] доставлен!" или "Заказ №[order_id] отменен").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `OrderMeta`, который автоматически регистрирует все подклассы `Order` в реестре. Это позволит динамически создавать экземпляры заказов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `OrderFactory` с методом `create_order`, который принимает тип заказа (например, `"online"`, `"phone"`, `"store"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания заказов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на отмену заказа. Например:
#      - Оператор колл-центра может одобрить отмену заказа, если он еще не отправлен.
#      - Менеджер может одобрить отмену заказа, если он уже отправлен, но не доставлен.
#      - Администратор может одобрить отмену любого заказа.
#    - Создайте цепочку обработчиков (`CallCenterOperator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса расчета стоимости заказа. Создайте базовый класс `TotalCalculator` с методом `calculate_total`, который определяет общую структуру расчета:
#      - Получение базовой стоимости товаров.
#      - Применение скидок или дополнительных сборов.
#      - Возврат итоговой стоимости.
#    - Подклассы (`OnlineOrderCalculator`, `PhoneOrderCalculator`) должны реализовывать конкретные шаги расчета.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, отмена заказа или изменение статуса). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidOrderError`: если заказ содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `OrderNotFoundError`: если заказ не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о заказах в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения заказов по стоимости, дате или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание заказов:
#    - Используйте `OrderFactory` для создания заказов разных типов.
#    - Добавьте товары в заказ с помощью метода `add_item`.
#
# 2. Управление данными:
#    - Редактируйте данные заказов через сеттеры.
#    - Удаляйте товары из заказа с помощью метода `remove_item`.
#
# 3. Анализ данных:
#    - Получите список всех заказов клиента с помощью метода `get_order_history`.
#    - Отслеживайте статус заказа с помощью метода `track_status`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке создания заказа с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 5. Учет и управление библиотекой
#
# Разработайте программное обеспечение для учета и управления библиотекой. Программа должна предоставлять возможность создания записей о книгах, авторах, читателях, выдачах книг и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `LibraryItem` (библиотечный ресурс)**
#    - Создайте абстрактный класс `LibraryItem`, который будет являться базовым для всех типов библиотечных ресурсов (книги, журналы, аудиокниги и т.д.).
#    - В классе определите:
#      - Абстрактный метод `get_description`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех ресурсов: `title` (название), `author` (автор), `year` (год издания), `item_id` (идентификатор ресурса), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Название: [title], Автор: [author]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения ресурсов по году издания или названию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов библиотечных ресурсов:
#      - `Book` (книга): добавьте атрибут `genre` (жанр).
#      - `Magazine` (журнал): добавьте атрибут `issue_number` (номер выпуска).
#      - `Audiobook` (аудиокнига): добавьте атрибут `duration` (продолжительность).
#    - В каждом подклассе переопределите метод `get_description` для вывода дополнительной информации (например, "Книга: [title], Жанр: [genre]").
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Аудиокнига: [title], Продолжительность: [duration] минут").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Reader`, который будет содержать информацию о читателе:
#      - Атрибуты: `name` (имя), `reader_id` (идентификатор читателя), `borrowed_items` (список взятых ресурсов).
#      - Методы: `borrow_item` (взять ресурс), `return_item` (вернуть ресурс), `get_borrowed_items` (получить список взятых ресурсов).
#    - Используйте **композицию**: добавьте атрибут `address` (адрес читателя) через отдельный класс `Address`.
#    - Используйте **агрегацию**: читатель может существовать без взятых ресурсов, но ресурсы могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с библиотекой**
#    - Создайте интерфейс `Searchable`, который определяет метод `search_by_title`. Этот метод должен быть реализован для поиска ресурсов по названию.
#    - Добавьте второй интерфейс `Reservable`, который определяет метод `reserve_item`. Этот метод должен быть реализован для бронирования ресурса (например, "Ресурс [title] забронирован для [reader_name]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с ресурсами. Например, метод `log_action`, который записывает действия (например, "Ресурс [title] выдан читателю [reader_name]").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ресурс [title] готов к выдаче" или "Ресурс [title] просрочен").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `LibraryItemMeta`, который автоматически регистрирует все подклассы `LibraryItem` в реестре. Это позволит динамически создавать экземпляры ресурсов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `LibraryItemFactory` с методом `create_item`, который принимает тип ресурса (например, `"book"`, `"magazine"`, `"audiobook"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания ресурсов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на продление срока выдачи ресурса. Например:
#      - Библиотекарь может одобрить продление на 1 неделю.
#      - Заведующий библиотекой может одобрить продление на 2 недели.
#      - Директор библиотеки может одобрить любое продление.
#    - Создайте цепочку обработчиков (`Librarian`, `HeadLibrarian`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса выдачи ресурса. Создайте базовый класс `BorrowProcess` с методом `borrow_item`, который определяет общую структуру процесса:
#      - Проверка доступности ресурса.
#      - Обновление статуса ресурса.
#      - Добавление ресурса в список взятых у читателя.
#    - Подклассы (`BookBorrowProcess`, `AudiobookBorrowProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, выдача ресурса или продление срока). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `ItemNotAvailableError`: если ресурс недоступен для выдачи.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `ReaderNotFoundError`: если читатель не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о ресурсах и читателях в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения ресурсов по году издания, названию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание ресурсов:
#    - Используйте `LibraryItemFactory` для создания ресурсов разных типов.
#    - Добавьте ресурсы в библиотеку с помощью метода `add_item`.
#
# 2. Управление данными:
#    - Редактируйте данные ресурсов через сеттеры.
#    - Удаляйте ресурсы из библиотеки с помощью метода `remove_item`.
#
# 3. Анализ данных:
#    - Получите список всех ресурсов библиотеки с помощью метода `get_all_items`.
#    - Найдите ресурсы по названию с помощью метода `search_by_title`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке выдачи недоступного ресурса или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 6. Учет и управление транспортной компанией
#
# Разработайте программное обеспечение для учета и управления транспортной компанией. Программа должна предоставлять возможность создания записей о транспортных средствах, водителях, маршрутах, рейсах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Vehicle` (транспортное средство)**
#    - Создайте абстрактный класс `Vehicle`, который будет являться базовым для всех типов транспортных средств.
#    - В классе определите:
#      - Абстрактный метод `calculate_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех транспортных средств: `vehicle_id` (идентификатор), `model` (модель), `year` (год выпуска), `capacity` (вместимость), `status` (статус).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Транспортное средство: [model], Год выпуска: [year]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения транспортных средств по году выпуска или вместимости.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов транспортных средств:
#      - `Bus` (автобус): добавьте атрибут `route_number` (номер маршрута).
#      - `Truck` (грузовик): добавьте атрибут `cargo_capacity` (грузоподъемность).
#      - `Taxi` (такси): добавьте атрибут `license_plate` (номерной знак).
#    - В каждом подклассе переопределите метод `calculate_cost` для расчета стоимости эксплуатации в зависимости от типа транспортного средства.
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Автобус: [model], Номер маршрута: [route_number]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Driver`, который будет содержать информацию о водителе:
#      - Атрибуты: `name` (имя), `driver_id` (идентификатор водителя), `license_type` (тип водительских прав), `assigned_vehicle` (закрепленное транспортное средство).
#      - Методы: `assign_vehicle` (закрепить транспортное средство), `remove_vehicle` (открепить транспортное средство), `get_assigned_vehicle` (получить закрепленное транспортное средство).
#    - Используйте **композицию**: добавьте атрибут `address` (адрес водителя) через отдельный класс `Address`.
#    - Используйте **агрегацию**: водитель может существовать без закрепленного транспортного средства, но транспортное средство может быть закреплено позже.
#
# #### 4. **Интерфейсы для работы с транспортной компанией**
#    - Создайте интерфейс `Trackable`, который определяет метод `track_location`. Этот метод должен быть реализован для отслеживания текущего местоположения транспортного средства.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о рейсах (например, "Отчет по рейсу: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с транспортными средствами. Например, метод `log_action`, который записывает действия (например, "Транспортное средство [model] отправлено в рейс").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Транспортное средство [model] требует технического обслуживания").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `VehicleMeta`, который автоматически регистрирует все подклассы `Vehicle` в реестре. Это позволит динамически создавать экземпляры транспортных средств по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `VehicleFactory` с методом `create_vehicle`, который принимает тип транспортного средства (например, `"bus"`, `"truck"`, `"taxi"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания транспортных средств в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на техническое обслуживание. Например:
#      - Механик может одобрить обслуживание, если оно не требует больших затрат.
#      - Руководитель отдела может одобрить обслуживание, если затраты средние.
#      - Директор компании может одобрить любое обслуживание.
#    - Создайте цепочку обработчиков (`Mechanic`, `DepartmentHead`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса расчета стоимости эксплуатации. Создайте базовый класс `CostCalculator` с методом `calculate_cost`, который определяет общую структуру расчета:
#      - Получение базовой стоимости эксплуатации.
#      - Применение дополнительных расходов.
#      - Возврат итоговой стоимости.
#    - Подклассы (`BusCostCalculator`, `TruckCostCalculator`) должны реализовывать конкретные шаги расчета.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, назначение водителя или изменение статуса транспортного средства). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidVehicleError`: если транспортное средство содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `DriverNotFoundError`: если водитель не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о транспортных средствах и водителях в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения транспортных средств по году выпуска, вместимости или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание транспортных средств:
#    - Используйте `VehicleFactory` для создания транспортных средств разных типов.
#    - Добавьте транспортные средства в парк с помощью метода `add_vehicle`.
#
# 2. Управление данными:
#    - Редактируйте данные транспортных средств через сеттеры.
#    - Удаляйте транспортные средства из парка с помощью метода `remove_vehicle`.
#
# 3. Анализ данных:
#    - Получите список всех транспортных средств с помощью метода `get_all_vehicles`.
#    - Найдите транспортные средства по модели с помощью метода `search_by_model`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке назначения водителя с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 7. Учет и управление фитнес-клубом
#
# Разработайте программное обеспечение для учета и управления фитнес-клубом. Программа должна предоставлять возможность создания записей о клиентах, тренерах, абонементах, тренировках и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Member` (участник)**
#    - Создайте абстрактный класс `Member`, который будет являться базовым для всех типов участников (клиенты, тренеры).
#    - В классе определите:
#      - Абстрактный метод `get_membership_info`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех участников: `member_id` (идентификатор), `name` (имя), `age` (возраст), `membership_type` (тип членства), `join_date` (дата вступления).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Участник: [name], Тип членства: [membership_type]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения участников по возрасту или дате вступления.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов участников:
#      - `Client` (клиент): добавьте атрибут `subscription` (абонемент).
#      - `Trainer` (тренер): добавьте атрибут `specialization` (специализация).
#    - В каждом подклассе переопределите метод `get_membership_info` для вывода дополнительной информации (например, "Клиент: [name], Абонемент: [subscription]").
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Тренер: [name], Специализация: [specialization]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `GymClass`, который будет содержать информацию о групповых тренировках:
#      - Атрибуты: `class_name` (название тренировки), `trainer` (тренер), `schedule` (расписание), `participants` (список участников).
#      - Методы: `add_participant` (добавить участника), `remove_participant` (удалить участника), `get_participants` (получить список участников).
#    - Используйте **композицию**: добавьте атрибут `location` (место проведения тренировки) через отдельный класс `Location`.
#    - Используйте **агрегацию**: тренировка может существовать без участников, но участники могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с фитнес-клубом**
#    - Создайте интерфейс `Bookable`, который определяет метод `book_class`. Этот метод должен быть реализован для записи участника на тренировку.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о тренировках (например, "Отчет по тренировке: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с участниками и тренировками. Например, метод `log_action`, который записывает действия (например, "Участник [name] записан на тренировку [class_name]").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Тренировка [class_name] отменена" или "Ваш абонемент истекает").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `MemberMeta`, который автоматически регистрирует все подклассы `Member` в реестре. Это позволит динамически создавать экземпляры участников по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `MemberFactory` с методом `create_member`, который принимает тип участника (например, `"client"`, `"trainer"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания участников в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на продление абонемента. Например:
#      - Администратор может одобрить продление на 1 месяц.
#      - Менеджер может одобрить продление на 3 месяца.
#      - Директор клуба может одобрить любое продление.
#    - Создайте цепочку обработчиков (`Administrator`, `Manager`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса записи на тренировку. Создайте базовый класс `BookingProcess` с методом `book_class`, который определяет общую структуру процесса:
#      - Проверка доступности тренировки.
#      - Добавление участника в список.
#      - Подтверждение записи.
#    - Подклассы (`ClientBookingProcess`, `TrainerBookingProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, запись на тренировку или продление абонемента). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidMemberError`: если участник содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `ClassFullError`: если тренировка переполнена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об участниках и тренировках в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения участников по возрасту, дате вступления или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание участников:
#    - Используйте `MemberFactory` для создания участников разных типов.
#    - Добавьте участников в клуб с помощью метода `add_member`.
#
# 2. Управление данными:
#    - Редактируйте данные участников через сеттеры.
#    - Удаляйте участников из клуба с помощью метода `remove_member`.
#
# 3. Анализ данных:
#    - Получите список всех участников клуба с помощью метода `get_all_members`.
#    - Найдите участников по имени с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке записи на переполненную тренировку или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 8. Учет и управление рестораном
#
# Разработайте программное обеспечение для учета и управления рестораном. Программа должна предоставлять возможность создания записей о блюдах, ингредиентах, сотрудниках, заказах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `MenuItem` (пункт меню)**
#    - Создайте абстрактный класс `MenuItem`, который будет являться базовым для всех типов блюд и напитков.
#    - В классе определите:
#      - Абстрактный метод `calculate_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех пунктов меню: `item_id` (идентификатор), `name` (название), `price` (цена), `category` (категория), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Пункт меню: [name], Цена: [price]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения пунктов меню по цене или названию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов пунктов меню:
#      - `Dish` (блюдо): добавьте атрибут `ingredients` (список ингредиентов).
#      - `Drink` (напиток): добавьте атрибут `volume` (объем).
#      - `Dessert` (десерт): добавьте атрибут `calories` (калорийность).
#    - В каждом подклассе переопределите метод `calculate_cost` для расчета стоимости с учетом дополнительных факторов (например, сезонные скидки).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Блюдо: [name], Ингредиенты: [ingredients]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Order`, который будет содержать информацию о заказе:
#      - Атрибуты: `order_id` (идентификатор заказа), `customer` (клиент), `items` (список пунктов меню), `total_cost` (общая стоимость).
#      - Методы: `add_item` (добавить пункт меню), `remove_item` (удалить пункт меню), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `table_number` (номер стола) через отдельный класс `Table`.
#    - Используйте **агрегацию**: заказ может существовать без пунктов меню, но пункты могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с рестораном**
#    - Создайте интерфейс `Preparable`, который определяет метод `prepare`. Этот метод должен быть реализован для описания процесса приготовления блюда или напитка.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о заказах (например, "Отчет по заказу: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с заказами и пунктами меню. Например, метод `log_action`, который записывает действия (например, "Заказ №[order_id] создан").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Заказ №[order_id] готов" или "Пункт меню [name] закончился").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `MenuItemMeta`, который автоматически регистрирует все подклассы `MenuItem` в реестре. Это позволит динамически создавать экземпляры пунктов меню по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `MenuItemFactory` с методом `create_item`, который принимает тип пункта меню (например, `"dish"`, `"drink"`, `"dessert"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания пунктов меню в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение заказа. Например:
#      - Официант может одобрить изменение заказа, если оно незначительное.
#      - Шеф-повар может одобрить изменение заказа, если оно требует пересмотра ингредиентов.
#      - Управляющий может одобрить любое изменение заказа.
#    - Создайте цепочку обработчиков (`Waiter`, `Chef`, `Manager`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса приготовления блюда. Создайте базовый класс `CookingProcess` с методом `prepare`, который определяет общую структуру процесса:
#      - Подготовка ингредиентов.
#      - Приготовление блюда.
#      - Подача блюда.
#    - Подклассы (`DishCookingProcess`, `DrinkCookingProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, изменение заказа или добавление пункта меню). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidItemError`: если пункт меню содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `OrderNotFoundError`: если заказ не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о заказах и пунктах меню в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения пунктов меню по цене, названию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание пунктов меню:
#    - Используйте `MenuItemFactory` для создания пунктов меню разных типов.
#    - Добавьте пункты меню в меню ресторана с помощью метода `add_item`.
#
# 2. Управление данными:
#    - Редактируйте данные пунктов меню через сеттеры.
#    - Удаляйте пункты меню из меню с помощью метода `remove_item`.
#
# 3. Анализ данных:
#    - Получите список всех пунктов меню с помощью метода `get_all_items`.
#    - Найдите пункты меню по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке создания заказа с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 9. Учет и управление кинотеатром
#
# Разработайте программное обеспечение для учета и управления кинотеатром. Программа должна предоставлять возможность создания записей о фильмах, сеансах, залах, билетах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Movie` (фильм)**
#    - Создайте абстрактный класс `Movie`, который будет являться базовым для всех типов фильмов.
#    - В классе определите:
#      - Абстрактный метод `get_movie_info`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех фильмов: `movie_id` (идентификатор), `title` (название), `duration` (продолжительность), `genre` (жанр), `rating` (рейтинг).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Фильм: [title], Жанр: [genre]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения фильмов по продолжительности или рейтингу.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов фильмов:
#      - `ActionMovie` (боевик): добавьте атрибут `action_scenes` (количество экшен-сцен).
#      - `ComedyMovie` (комедия): добавьте атрибут `jokes_count` (количество шуток).
#      - `DramaMovie` (драма): добавьте атрибут `emotional_score` (эмоциональный рейтинг).
#    - В каждом подклассе переопределите метод `get_movie_info` для вывода дополнительной информации (например, "Боевик: [title], Экшен-сцены: [action_scenes]").
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Комедия: [title], Шутки: [jokes_count]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Screening`, который будет содержать информацию о сеансе:
#      - Атрибуты: `screening_id` (идентификатор сеанса), `movie` (фильм), `hall` (зал), `start_time` (время начала), `tickets_sold` (количество проданных билетов).
#      - Методы: `add_ticket` (добавить билет), `remove_ticket` (удалить билет), `get_available_seats` (получить количество свободных мест).
#    - Используйте **композицию**: добавьте атрибут `hall_info` (информация о зале) через отдельный класс `Hall`.
#    - Используйте **агрегацию**: сеанс может существовать без проданных билетов, но билеты могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с кинотеатром**
#    - Создайте интерфейс `Bookable`, который определяет метод `book_ticket`. Этот метод должен быть реализован для бронирования билета на сеанс.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о сеансах (например, "Отчет по сеансу: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с сеансами и билетами. Например, метод `log_action`, который записывает действия (например, "Билет на сеанс [screening_id] продан").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш билет на фильм [title] готов" или "Сеанс [screening_id] отменен").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `MovieMeta`, который автоматически регистрирует все подклассы `Movie` в реестре. Это позволит динамически создавать экземпляры фильмов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `MovieFactory` с методом `create_movie`, который принимает тип фильма (например, `"action"`, `"comedy"`, `"drama"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания фильмов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на возврат билетов. Например:
#      - Кассир может одобрить возврат, если он сделан за 24 часа до сеанса.
#      - Менеджер может одобрить возврат, если он сделан за 1 час до сеанса.
#      - Администратор может одобрить любой возврат.
#    - Создайте цепочку обработчиков (`Cashier`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса бронирования билета. Создайте базовый класс `BookingProcess` с методом `book_ticket`, который определяет общую структуру процесса:
#      - Проверка доступности мест.
#      - Бронирование билета.
#      - Подтверждение брони.
#    - Подклассы (`OnlineBookingProcess`, `OfflineBookingProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, бронирование билета или отмена сеанса). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidMovieError`: если фильм содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `ScreeningNotFoundError`: если сеанс не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о фильмах и сеансах в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения фильмов по продолжительности, рейтингу или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
# ### Пример использования программы
#
# 1. Создание фильмов:
#    - Используйте `MovieFactory` для создания фильмов разных типов.
#    - Добавьте фильмы в расписание с помощью метода `add_movie`.
#
# 2. Управление данными:
#    - Редактируйте данные фильмов через сеттеры.
#    - Удаляйте фильмы из расписания с помощью метода `remove_movie`.
#
# 3. Анализ данных:
#    - Получите список всех фильмов с помощью метода `get_all_movies`.
#    - Найдите фильмы по названию с помощью метода `search_by_title`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке бронирования билета с некорректными данными или при отсутствии прав доступа.
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 10. Учет и управление гостиницей
#
# Разработайте программное обеспечение для учета и управления гостиницей. Программа должна предоставлять возможность создания записей о номерах, клиентах, бронированиях, услугах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Room` (номер)**
#    - Создайте абстрактный класс `Room`, который будет являться базовым для всех типов номеров.
#    - В классе определите:
#      - Абстрактный метод `calculate_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех номеров: `room_id` (идентификатор), `room_type` (тип номера), `capacity` (вместимость), `price_per_night` (цена за ночь), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Номер: [room_id], Тип: [room_type]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения номеров по цене или вместимости.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов номеров:
#      - `StandardRoom` (стандартный номер): добавьте атрибут `has_tv` (наличие телевизора).
#      - `DeluxeRoom` (люкс): добавьте атрибут `has_jacuzzi` (наличие джакузи).
#      - `Suite` (апартаменты): добавьте атрибут `number_of_rooms` (количество комнат).
#    - В каждом подклассе переопределите метод `calculate_cost` для расчета стоимости с учетом дополнительных услуг.
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Люкс: [room_id], Джакузи: [has_jacuzzi]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Booking`, который будет содержать информацию о бронировании:
#      - Атрибуты: `booking_id` (идентификатор бронирования), `customer` (клиент), `room` (номер), `check_in_date` (дата заезда), `check_out_date` (дата выезда), `total_cost` (общая стоимость).
#      - Методы: `add_service` (добавить услугу), `remove_service` (удалить услугу), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: бронирование может существовать без дополнительных услуг, но услуги могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с гостиницей**
#    - Создайте интерфейс `Bookable`, который определяет метод `book_room`. Этот метод должен быть реализован для бронирования номера.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о бронированиях (например, "Отчет по бронированию: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с бронированиями и номерами. Например, метод `log_action`, который записывает действия (например, "Бронирование [booking_id] создано").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш номер [room_id] готов" или "Бронирование [booking_id] отменено").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `RoomMeta`, который автоматически регистрирует все подклассы `Room` в реестре. Это позволит динамически создавать экземпляры номеров по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `RoomFactory` с методом `create_room`, который принимает тип номера (например, `"standard"`, `"deluxe"`, `"suite"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания номеров в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение бронирования. Например:
#      - Администратор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Директор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Administrator`, `Manager`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса бронирования номера. Создайте базовый класс `BookingProcess` с методом `book_room`, который определяет общую структуру процесса:
#      - Проверка доступности номера.
#      - Бронирование номера.
#      - Подтверждение брони.
#    - Подклассы (`OnlineBookingProcess`, `OfflineBookingProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, бронирование номера или изменение бронирования). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidRoomError`: если номер содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `BookingNotFoundError`: если бронирование не найдено.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о номерах и бронированиях в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения номеров по цене, вместимости или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание номеров:
#    - Используйте `RoomFactory` для создания номеров разных типов.
#    - Добавьте номера в гостиницу с помощью метода `add_room`.
#
# 2. Управление данными:
#    - Редактируйте данные номеров через сеттеры.
#    - Удаляйте номера из гостиницы с помощью метода `remove_room`.
#
# 3. Анализ данных:
#    - Получите список всех номеров с помощью метода `get_all_rooms`.
#    - Найдите номера по типу с помощью метода `search_by_type`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке бронирования номера с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 11. Учет и управление автосалоном
#
# Разработайте программное обеспечение для учета и управления автосалоном. Программа должна предоставлять возможность создания записей о автомобилях, клиентах, продажах, услугах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Car` (автомобиль)**
#    - Создайте абстрактный класс `Car`, который будет являться базовым для всех типов автомобилей.
#    - В классе определите:
#      - Абстрактный метод `calculate_price`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех автомобилей: `car_id` (идентификатор), `make` (марка), `model` (модель), `year` (год выпуска), `price` (цена), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Автомобиль: [make] [model], Год выпуска: [year]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения автомобилей по цене или году выпуска.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов автомобилей:
#      - `Sedan` (седан): добавьте атрибут `fuel_efficiency` (расход топлива).
#      - `SUV` (внедорожник): добавьте атрибут `towing_capacity` (грузоподъемность).
#      - `ElectricCar` (электромобиль): добавьте атрибут `battery_range` (запас хода).
#    - В каждом подклассе переопределите метод `calculate_price` для расчета стоимости с учетом дополнительных факторов (например, скидки на электромобили).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Седан: [make] [model], Расход топлива: [fuel_efficiency]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Sale`, который будет содержать информацию о продаже:
#      - Атрибуты: `sale_id` (идентификатор продажи), `customer` (клиент), `car` (автомобиль), `sale_date` (дата продажи), `total_price` (общая стоимость).
#      - Методы: `add_accessory` (добавить аксессуар), `remove_accessory` (удалить аксессуар), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: продажа может существовать без аксессуаров, но аксессуары могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с автосалоном**
#    - Создайте интерфейс `Sellable`, который определяет метод `sell_car`. Этот метод должен быть реализован для оформления продажи автомобиля.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о продажах (например, "Отчет по продаже: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с продажами и автомобилями. Например, метод `log_action`, который записывает действия (например, "Продажа [sale_id] оформлена").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш автомобиль [make] [model] готов к выдаче" или "Продажа [sale_id] отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `CarMeta`, который автоматически регистрирует все подклассы `Car` в реестре. Это позволит динамически создавать экземпляры автомобилей по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `CarFactory` с методом `create_car`, который принимает тип автомобиля (например, `"sedan"`, `"suv"`, `"electric"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания автомобилей в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение цены автомобиля. Например:
#      - Менеджер по продажам может одобрить изменение цены, если оно незначительное.
#      - Финансовый отдел может одобрить изменение цены, если оно требует пересмотра бюджета.
#      - Директор может одобрить любое изменение цены.
#    - Создайте цепочку обработчиков (`SalesManager`, `FinanceDepartment`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса продажи автомобиля. Создайте базовый класс `SaleProcess` с методом `sell_car`, который определяет общую структуру процесса:
#      - Проверка доступности автомобиля.
#      - Оформление продажи.
#      - Подтверждение продажи.
#    - Подклассы (`OnlineSaleProcess`, `OfflineSaleProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, оформление продажи или изменение цены). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidCarError`: если автомобиль содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `SaleNotFoundError`: если продажа не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о автомобилях и продажах в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения автомобилей по цене, году выпуска или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание автомобилей:
#    - Используйте `CarFactory` для создания автомобилей разных типов.
#    - Добавьте автомобили в автосалон с помощью метода `add_car`.
#
# 2. Управление данными:
#    - Редактируйте данные автомобилей через сеттеры.
#    - Удаляйте автомобили из автосалона с помощью метода `remove_car`.
#
# 3. Анализ данных:
#    - Получите список всех автомобилей с помощью метода `get_all_cars`.
#    - Найдите автомобили по марке с помощью метода `search_by_make`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке оформления продажи с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 12. Учет и управление медицинской клиникой
#
# Разработайте программное обеспечение для учета и управления медицинской клиникой. Программа должна предоставлять возможность создания записей о пациентах, врачах, приемах, услугах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Patient` (пациент)**
#    - Создайте абстрактный класс `Patient`, который будет являться базовым для всех типов пациентов.
#    - В классе определите:
#      - Абстрактный метод `get_medical_history`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех пациентов: `patient_id` (идентификатор), `name` (имя), `age` (возраст), `gender` (пол), `medical_history` (история болезней).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Пациент: [name], Возраст: [age]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения пациентов по возрасту или количеству записей в истории болезней.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов пациентов:
#      - `AdultPatient` (взрослый пациент): добавьте атрибут `occupation` (род занятий).
#      - `ChildPatient` (ребенок): добавьте атрибут `guardian` (опекун).
#      - `SeniorPatient` (пожилой пациент): добавьте атрибут `chronic_conditions` (хронические заболевания).
#    - В каждом подклассе переопределите метод `get_medical_history` для вывода дополнительной информации (например, "Взрослый пациент: [name], Род занятий: [occupation]").
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Ребенок: [name], Опекун: [guardian]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Appointment`, который будет содержать информацию о приеме:
#      - Атрибуты: `appointment_id` (идентификатор приема), `patient` (пациент), `doctor` (врач), `date` (дата приема), `diagnosis` (диагноз), `prescription` (рецепт).
#      - Методы: `add_service` (добавить услугу), `remove_service` (удалить услугу), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `doctor_info` (информация о враче) через отдельный класс `Doctor`.
#    - Используйте **агрегацию**: прием может существовать без дополнительных услуг, но услуги могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с клиникой**
#    - Создайте интерфейс `Schedulable`, который определяет метод `schedule_appointment`. Этот метод должен быть реализован для записи на прием.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о приемах (например, "Отчет по приему: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с приемами и пациентами. Например, метод `log_action`, который записывает действия (например, "Прием [appointment_id] создан").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш прием на [date] подтвержден" или "Прием [appointment_id] отменен").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `PatientMeta`, который автоматически регистрирует все подклассы `Patient` в реестре. Это позволит динамически создавать экземпляры пациентов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `PatientFactory` с методом `create_patient`, который принимает тип пациента (например, `"adult"`, `"child"`, `"senior"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания пациентов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение диагноза. Например:
#      - Врач может одобрить изменение, если оно незначительное.
#      - Заведующий отделением может одобрить изменение, если оно требует пересмотра лечения.
#      - Главный врач может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Doctor`, `DepartmentHead`, `ChiefPhysician`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса записи на прием. Создайте базовый класс `AppointmentProcess` с методом `schedule_appointment`, который определяет общую структуру процесса:
#      - Проверка доступности врача.
#      - Запись на прием.
#      - Подтверждение записи.
#    - Подклассы (`OnlineAppointmentProcess`, `OfflineAppointmentProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, запись на прием или изменение диагноза). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidPatientError`: если пациент содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `AppointmentNotFoundError`: если прием не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о пациентах и приемах в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения пациентов по возрасту, количеству записей в истории болезней или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание пациентов:
#    - Используйте `PatientFactory` для создания пациентов разных типов.
#    - Добавьте пациентов в клинику с помощью метода `add_patient`.
#
# 2. Управление данными:
#    - Редактируйте данные пациентов через сеттеры.
#    - Удаляйте пациентов из клиники с помощью метода `remove_patient`.
#
# 3. Анализ данных:
#    - Получите список всех пациентов с помощью метода `get_all_patients`.
#    - Найдите пациентов по имени с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке записи на прием с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 13. Учет и управление образовательным учреждением
#
# Разработайте программное обеспечение для учета и управления образовательным учреждением (школа, университет, курсы). Программа должна предоставлять возможность создания записей о студентах, преподавателях, курсах, оценках и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Person` (человек)**
#    - Создайте абстрактный класс `Person`, который будет являться базовым для всех типов участников образовательного процесса (студенты, преподаватели).
#    - В классе определите:
#      - Абстрактный метод `get_role`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех участников: `person_id` (идентификатор), `name` (имя), `age` (возраст), `email` (электронная почта).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Человек: [name], Возраст: [age]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения участников по возрасту или имени.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов участников:
#      - `Student` (студент): добавьте атрибут `student_id` (идентификатор студента), `courses` (список курсов), `grades` (оценки).
#      - `Teacher` (преподаватель): добавьте атрибут `teacher_id` (идентификатор преподавателя), `subjects` (список преподаваемых предметов).
#    - В каждом подклассе переопределите метод `get_role` для вывода роли участника (например, "Студент: [name], Курсы: [courses]").
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Преподаватель: [name], Предметы: [subjects]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Course`, который будет содержать информацию о курсе:
#      - Атрибуты: `course_id` (идентификатор курса), `course_name` (название курса), `teacher` (преподаватель), `students` (список студентов), `schedule` (расписание).
#      - Методы: `add_student` (добавить студента), `remove_student` (удалить студента), `get_students` (получить список студентов).
#    - Используйте **композицию**: добавьте атрибут `course_materials` (материалы курса) через отдельный класс `Materials`.
#    - Используйте **агрегацию**: курс может существовать без студентов, но студенты могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с образовательным учреждением**
#    - Создайте интерфейс `Enrollable`, который определяет метод `enroll_student`. Этот метод должен быть реализован для записи студента на курс.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о курсах (например, "Отчет по курсу: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с курсами и студентами. Например, метод `log_action`, который записывает действия (например, "Студент [name] записан на курс [course_name]").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Вы записаны на курс [course_name]" или "Курс [course_name] отменен").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `PersonMeta`, который автоматически регистрирует все подклассы `Person` в реестре. Это позволит динамически создавать экземпляры участников по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `PersonFactory` с методом `create_person`, который принимает тип участника (например, `"student"`, `"teacher"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания участников в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение оценки студента. Например:
#      - Преподаватель может одобрить изменение, если оно незначительное.
#      - Заведующий кафедрой может одобрить изменение, если оно требует пересмотра.
#      - Декан может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Teacher`, `DepartmentHead`, `Dean`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса записи студента на курс. Создайте базовый класс `EnrollmentProcess` с методом `enroll_student`, который определяет общую структуру процесса:
#      - Проверка доступности курса.
#      - Запись студента на курс.
#      - Подтверждение записи.
#    - Подклассы (`OnlineEnrollmentProcess`, `OfflineEnrollmentProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, запись на курс или изменение оценки). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidPersonError`: если участник содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `CourseNotFoundError`: если курс не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о студентах, преподавателях и курсах в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения участников по возрасту, количеству курсов или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание участников:
#    - Используйте `PersonFactory` для создания студентов и преподавателей.
#    - Добавьте участников в образовательное учреждение с помощью метода `add_person`.
#
# 2. Управление данными:
#    - Редактируйте данные участников через сеттеры.
#    - Удаляйте участников из системы с помощью метода `remove_person`.
#
# 3. Анализ данных:
#    - Получите список всех студентов с помощью метода `get_all_students`.
#    - Найдите студентов по имени с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке записи на курс с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 14. Учет и управление туристическим агентством
#
# Разработайте программное обеспечение для учета и управления туристическим агентством. Программа должна предоставлять возможность создания записей о турах, клиентах, бронированиях, услугах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Tour` (тур)**
#    - Создайте абстрактный класс `Tour`, который будет являться базовым для всех типов туров.
#    - В классе определите:
#      - Абстрактный метод `calculate_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех туров: `tour_id` (идентификатор), `destination` (направление), `duration` (продолжительность), `price` (цена), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Тур: [destination], Продолжительность: [duration] дней").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения туров по цене или продолжительности.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов туров:
#      - `BeachTour` (пляжный тур): добавьте атрибут `beach_type` (тип пляжа).
#      - `AdventureTour` (приключенческий тур): добавьте атрибут `activities` (список активностей).
#      - `CulturalTour` (культурный тур): добавьте атрибут `historical_sites` (список исторических мест).
#    - В каждом подклассе переопределите метод `calculate_cost` для расчета стоимости с учетом дополнительных факторов (например, сезонные скидки).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Пляжный тур: [destination], Тип пляжа: [beach_type]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Booking`, который будет содержать информацию о бронировании:
#      - Атрибуты: `booking_id` (идентификатор бронирования), `customer` (клиент), `tour` (тур), `booking_date` (дата бронирования), `total_cost` (общая стоимость).
#      - Методы: `add_service` (добавить услугу), `remove_service` (удалить услугу), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: бронирование может существовать без дополнительных услуг, но услуги могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с туристическим агентством**
#    - Создайте интерфейс `Bookable`, который определяет метод `book_tour`. Этот метод должен быть реализован для бронирования тура.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о бронированиях (например, "Отчет по бронированию: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с бронированиями и турами. Например, метод `log_action`, который записывает действия (например, "Бронирование [booking_id] создано").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш тур [destination] подтвержден" или "Бронирование [booking_id] отменено").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `TourMeta`, который автоматически регистрирует все подклассы `Tour` в реестре. Это позволит динамически создавать экземпляры туров по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `TourFactory` с методом `create_tour`, который принимает тип тура (например, `"beach"`, `"adventure"`, `"cultural"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания туров в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение бронирования. Например:
#      - Менеджер по продажам может одобрить изменение, если оно незначительное.
#      - Финансовый отдел может одобрить изменение, если оно требует пересмотра стоимости.
#      - Директор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`SalesManager`, `FinanceDepartment`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса бронирования тура. Создайте базовый класс `BookingProcess` с методом `book_tour`, который определяет общую структуру процесса:
#      - Проверка доступности тура.
#      - Бронирование тура.
#      - Подтверждение брони.
#    - Подклассы (`OnlineBookingProcess`, `OfflineBookingProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, бронирование тура или изменение бронирования). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidTourError`: если тур содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `BookingNotFoundError`: если бронирование не найдено.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о турах и бронированиях в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения туров по цене, продолжительности или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание туров:
#    - Используйте `TourFactory` для создания туров разных типов.
#    - Добавьте туры в агентство с помощью метода `add_tour`.
#
# 2. Управление данными:
#    - Редактируйте данные туров через сеттеры.
#    - Удаляйте туры из агентства с помощью метода `remove_tour`.
#
# 3. Анализ данных:
#    - Получите список всех туров с помощью метода `get_all_tours`.
#    - Найдите туры по направлению с помощью метода `search_by_destination`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке бронирования тура с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 15. Учет и управление спортивным клубом
#
# Разработайте программное обеспечение для учета и управления спортивным клубом. Программа должна предоставлять возможность создания записей о членах клуба, тренерах, тренировках, абонементах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Member` (член клуба)**
#    - Создайте абстрактный класс `Member`, который будет являться базовым для всех типов участников (клиенты, тренеры).
#    - В классе определите:
#      - Абстрактный метод `get_membership_info`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех участников: `member_id` (идентификатор), `name` (имя), `age` (возраст), `membership_type` (тип членства), `join_date` (дата вступления).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Член клуба: [name], Тип членства: [membership_type]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения участников по возрасту или дате вступления.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов участников:
#      - `Client` (клиент): добавьте атрибут `subscription` (абонемент).
#      - `Trainer` (тренер): добавьте атрибут `specialization` (специализация).
#    - В каждом подклассе переопределите метод `get_membership_info` для вывода дополнительной информации (например, "Клиент: [name], Абонемент: [subscription]").
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Тренер: [name], Специализация: [specialization]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `TrainingSession`, который будет содержать информацию о тренировке:
#      - Атрибуты: `session_id` (идентификатор тренировки), `trainer` (тренер), `participants` (список участников), `schedule` (расписание).
#      - Методы: `add_participant` (добавить участника), `remove_participant` (удалить участника), `get_participants` (получить список участников).
#    - Используйте **композицию**: добавьте атрибут `location` (место проведения тренировки) через отдельный класс `Location`.
#    - Используйте **агрегацию**: тренировка может существовать без участников, но участники могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с клубом**
#    - Создайте интерфейс `Bookable`, который определяет метод `book_session`. Этот метод должен быть реализован для записи участника на тренировку.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о тренировках (например, "Отчет по тренировке: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с тренировками и участниками. Например, метод `log_action`, который записывает действия (например, "Участник [name] записан на тренировку [session_id]").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Тренировка [session_id] отменена" или "Ваш абонемент истекает").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `MemberMeta`, который автоматически регистрирует все подклассы `Member` в реестре. Это позволит динамически создавать экземпляры участников по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `MemberFactory` с методом `create_member`, который принимает тип участника (например, `"client"`, `"trainer"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания участников в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на продление абонемента. Например:
#      - Администратор может одобрить продление на 1 месяц.
#      - Менеджер может одобрить продление на 3 месяца.
#      - Директор клуба может одобрить любое продление.
#    - Создайте цепочку обработчиков (`Administrator`, `Manager`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса записи на тренировку. Создайте базовый класс `BookingProcess` с методом `book_session`, который определяет общую структуру процесса:
#      - Проверка доступности тренировки.
#      - Запись участника на тренировку.
#      - Подтверждение записи.
#    - Подклассы (`OnlineBookingProcess`, `OfflineBookingProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, запись на тренировку или продление абонемента). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidMemberError`: если участник содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `SessionFullError`: если тренировка переполнена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об участниках и тренировках в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения участников по возрасту, дате вступления или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание участников:
#    - Используйте `MemberFactory` для создания участников разных типов.
#    - Добавьте участников в клуб с помощью метода `add_member`.
#
# 2. Управление данными:
#    - Редактируйте данные участников через сеттеры.
#    - Удаляйте участников из клуба с помощью метода `remove_member`.
#
# 3. Анализ данных:
#    - Получите список всех участников клуба с помощью метода `get_all_members`.
#    - Найдите участников по имени с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке записи на переполненную тренировку или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 16. Учет и управление библиотекой цифровых ресурсов
#
# Разработайте программное обеспечение для учета и управления библиотекой цифровых ресурсов (электронные книги, аудиокниги, фильмы, музыка). Программа должна предоставлять возможность создания записей о ресурсах, пользователях, загрузках, подписках и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `DigitalResource` (цифровой ресурс)**
#    - Создайте абстрактный класс `DigitalResource`, который будет являться базовым для всех типов цифровых ресурсов.
#    - В классе определите:
#      - Абстрактный метод `get_resource_info`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех ресурсов: `resource_id` (идентификатор), `title` (название), `author` (автор/создатель), `file_size` (размер файла), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Ресурс: [title], Автор: [author]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения ресурсов по размеру файла или названию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов цифровых ресурсов:
#      - `Ebook` (электронная книга): добавьте атрибут `page_count` (количество страниц).
#      - `Audiobook` (аудиокнига): добавьте атрибут `duration` (продолжительность).
#      - `Movie` (фильм): добавьте атрибут `resolution` (разрешение).
#      - `MusicTrack` (музыкальный трек): добавьте атрибут `genre` (жанр).
#    - В каждом подклассе переопределите метод `get_resource_info` для вывода дополнительной информации (например, "Электронная книга: [title], Страниц: [page_count]").
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Аудиокнига: [title], Продолжительность: [duration] минут").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `User`, который будет содержать информацию о пользователе:
#      - Атрибуты: `user_id` (идентификатор), `name` (имя), `email` (электронная почта), `subscription` (тип подписки), `downloaded_resources` (список загруженных ресурсов).
#      - Методы: `download_resource` (загрузить ресурс), `remove_resource` (удалить ресурс), `get_downloaded_resources` (получить список загруженных ресурсов).
#    - Используйте **композицию**: добавьте атрибут `subscription_info` (информация о подписке) через отдельный класс `Subscription`.
#    - Используйте **агрегацию**: пользователь может существовать без загруженных ресурсов, но ресурсы могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с библиотекой**
#    - Создайте интерфейс `Downloadable`, который определяет метод `download`. Этот метод должен быть реализован для загрузки ресурса.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о загрузках (например, "Отчет по загрузкам: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с ресурсами и пользователями. Например, метод `log_action`, который записывает действия (например, "Ресурс [title] загружен пользователем [name]").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш ресурс [title] готов к загрузке" или "Подписка истекает").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `ResourceMeta`, который автоматически регистрирует все подклассы `DigitalResource` в реестре. Это позволит динамически создавать экземпляры ресурсов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `ResourceFactory` с методом `create_resource`, который принимает тип ресурса (например, `"ebook"`, `"audiobook"`, `"movie"`, `"music"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания ресурсов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение подписки. Например:
#      - Менеджер по поддержке может одобрить изменение, если оно незначительное.
#      - Финансовый отдел может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`SupportManager`, `FinanceDepartment`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса загрузки ресурса. Создайте базовый класс `DownloadProcess` с методом `download`, который определяет общую структуру процесса:
#      - Проверка доступности ресурса.
#      - Загрузка ресурса.
#      - Подтверждение загрузки.
#    - Подклассы (`EbookDownloadProcess`, `AudiobookDownloadProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, загрузка ресурса или изменение подписки). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidResourceError`: если ресурс содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `ResourceNotFoundError`: если ресурс не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о ресурсах и пользователях в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения ресурсов по размеру файла, названию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание ресурсов:
#    - Используйте `ResourceFactory` для создания ресурсов разных типов.
#    - Добавьте ресурсы в библиотеку с помощью метода `add_resource`.
#
# 2. Управление данными:
#    - Редактируйте данные ресурсов через сеттеры.
#    - Удаляйте ресурсы из библиотеки с помощью метода `remove_resource`.
#
# 3. Анализ данных:
#    - Получите список всех ресурсов с помощью метода `get_all_resources`.
#    - Найдите ресурсы по названию с помощью метода `search_by_title`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке загрузки ресурса с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 17. Учет и управление сервисом аренды автомобилей
#
# Разработайте программное обеспечение для учета и управления сервисом аренды автомобилей. Программа должна предоставлять возможность создания записей о автомобилях, клиентах, аренде, оплате и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Car` (автомобиль)**
#    - Создайте абстрактный класс `Car`, который будет являться базовым для всех типов автомобилей.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех автомобилей: `car_id` (идентификатор), `make` (марка), `model` (модель), `year` (год выпуска), `daily_rate` (стоимость аренды за день), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Автомобиль: [make] [model], Год выпуска: [year]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения автомобилей по стоимости аренды или году выпуска.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов автомобилей:
#      - `EconomyCar` (экономичный автомобиль): добавьте атрибут `fuel_efficiency` (расход топлива).
#      - `LuxuryCar` (люксовый автомобиль): добавьте атрибут `premium_features` (список премиальных функций).
#      - `SUV` (внедорожник): добавьте атрибут `towing_capacity` (грузоподъемность).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Люксовый автомобиль: [make] [model], Премиальные функции: [premium_features]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `car` (автомобиль), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_extra` (добавить дополнительную услугу), `remove_extra` (удалить дополнительную услугу), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без дополнительных услуг, но услуги могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_car`. Этот метод должен быть реализован для аренды автомобиля.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и автомобилями. Например, метод `log_action`, который записывает действия (например, "Аренда [rental_id] создана").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш автомобиль [make] [model] готов к выдаче" или "Аренда [rental_id] отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `CarMeta`, который автоматически регистрирует все подклассы `Car` в реестре. Это позволит динамически создавать экземпляры автомобилей по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `CarFactory` с методом `create_car`, который принимает тип автомобиля (например, `"economy"`, `"luxury"`, `"suv"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания автомобилей в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Менеджер по аренде может одобрить изменение, если оно незначительное.
#      - Финансовый отдел может одобрить изменение, если оно требует пересмотра стоимости.
#      - Директор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`RentalManager`, `FinanceDepartment`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды автомобиля. Создайте базовый класс `RentalProcess` с методом `rent_car`, который определяет общую структуру процесса:
#      - Проверка доступности автомобиля.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда автомобиля или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidCarError`: если автомобиль содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об автомобилях и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения автомобилей по стоимости аренды, году выпуска или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание автомобилей:
#    - Используйте `CarFactory` для создания автомобилей разных типов.
#    - Добавьте автомобили в сервис с помощью метода `add_car`.
#
# 2. Управление данными:
#    - Редактируйте данные автомобилей через сеттеры.
#    - Удаляйте автомобили из сервиса с помощью метода `remove_car`.
#
# 3. Анализ данных:
#    - Получите список всех автомобилей с помощью метода `get_all_cars`.
#    - Найдите автомобили по марке с помощью метода `search_by_make`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды автомобиля с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 18. Учет и управление сервисом доставки еды
#
# Разработайте программное обеспечение для учета и управления сервисом доставки еды. Программа должна предоставлять возможность создания записей о ресторанах, блюдах, заказах, курьерах и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Dish` (блюдо)**
#    - Создайте абстрактный класс `Dish`, который будет являться базовым для всех типов блюд.
#    - В классе определите:
#      - Абстрактный метод `calculate_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех блюд: `dish_id` (идентификатор), `name` (название), `price` (цена), `ingredients` (список ингредиентов), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Блюдо: [name], Цена: [price]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения блюд по цене или названию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов блюд:
#      - `MainCourse` (основное блюдо): добавьте атрибут `calories` (калорийность).
#      - `Dessert` (десерт): добавьте атрибут `sugar_content` (содержание сахара).
#      - `Beverage` (напиток): добавьте атрибут `volume` (объем).
#    - В каждом подклассе переопределите метод `calculate_cost` для расчета стоимости с учетом дополнительных факторов (например, скидки на напитки).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Основное блюдо: [name], Калорийность: [calories]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Order`, который будет содержать информацию о заказе:
#      - Атрибуты: `order_id` (идентификатор заказа), `customer` (клиент), `dishes` (список блюд), `delivery_address` (адрес доставки), `total_cost` (общая стоимость).
#      - Методы: `add_dish` (добавить блюдо), `remove_dish` (удалить блюдо), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: заказ может существовать без блюд, но блюда могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Deliverable`, который определяет метод `deliver_order`. Этот метод должен быть реализован для доставки заказа.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов о заказах (например, "Отчет по заказу: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с заказами и блюдами. Например, метод `log_action`, который записывает действия (например, "Заказ [order_id] создан").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш заказ [order_id] готов к доставке" или "Заказ [order_id] отменен").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `DishMeta`, который автоматически регистрирует все подклассы `Dish` в реестре. Это позволит динамически создавать экземпляры блюд по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `DishFactory` с методом `create_dish`, который принимает тип блюда (например, `"main_course"`, `"dessert"`, `"beverage"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания блюд в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение заказа. Например:
#      - Оператор колл-центра может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`CallCenterOperator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса доставки заказа. Создайте базовый класс `DeliveryProcess` с методом `deliver_order`, который определяет общую структуру процесса:
#      - Подготовка заказа.
#      - Доставка заказа.
#      - Подтверждение доставки.
#    - Подклассы (`CourierDeliveryProcess`, `SelfPickupProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, изменение заказа или доставка). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidDishError`: если блюдо содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `OrderNotFoundError`: если заказ не найден.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о блюдах и заказах в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения блюд по цене, названию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание блюд:
#    - Используйте `DishFactory` для создания блюд разных типов.
#    - Добавьте блюда в меню с помощью метода `add_dish`.
#
# 2. Управление данными:
#    - Редактируйте данные блюд через сеттеры.
#    - Удаляйте блюда из меню с помощью метода `remove_dish`.
#
# 3. Анализ данных:
#    - Получите список всех блюд с помощью метода `get_all_dishes`.
#    - Найдите блюда по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке создания заказа с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 19. Учет и управление сервисом аренды жилья
#
# Разработайте программное обеспечение для учета и управления сервисом аренды жилья. Программа должна предоставлять возможность создания записей о недвижимости, владельцах, арендаторах, аренде, оплате и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Property` (недвижимость)**
#    - Создайте абстрактный класс `Property`, который будет являться базовым для всех типов недвижимости.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех типов недвижимости: `property_id` (идентификатор), `address` (адрес), `area` (площадь), `monthly_rate` (ежемесячная ставка аренды), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Недвижимость: [address], Площадь: [area] кв.м").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения недвижимости по ежемесячной ставке или площади.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов недвижимости:
#      - `Apartment` (квартира): добавьте атрибут `number_of_rooms` (количество комнат).
#      - `House` (дом): добавьте атрибут `has_garden` (наличие сада).
#      - `CommercialSpace` (коммерческое помещение): добавьте атрибут `business_type` (тип бизнеса).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на долгосрочную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Квартира: [address], Комнат: [number_of_rooms]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `RentalAgreement`, который будет содержать информацию об аренде:
#      - Атрибуты: `agreement_id` (идентификатор аренды), `tenant` (арендатор), `property` (недвижимость), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_extra` (добавить дополнительную услугу), `remove_extra` (удалить дополнительную услугу), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `tenant_info` (информация об арендаторе) через отдельный класс `Tenant`.
#    - Используйте **агрегацию**: аренда может существовать без дополнительных услуг, но услуги могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_property`. Этот метод должен быть реализован для аренды недвижимости.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и недвижимостью. Например, метод `log_action`, который записывает действия (например, "Аренда [agreement_id] создана").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваша аренда [address] подтверждена" или "Аренда [agreement_id] отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `PropertyMeta`, который автоматически регистрирует все подклассы `Property` в реестре. Это позволит динамически создавать экземпляры недвижимости по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `PropertyFactory` с методом `create_property`, который принимает тип недвижимости (например, `"apartment"`, `"house"`, `"commercial"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания недвижимости в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Менеджер по аренде может одобрить изменение, если оно незначительное.
#      - Финансовый отдел может одобрить изменение, если оно требует пересмотра стоимости.
#      - Директор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`RentalManager`, `FinanceDepartment`, `Director`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды недвижимости. Создайте базовый класс `RentalProcess` с методом `rent_property`, который определяет общую структуру процесса:
#      - Проверка доступности недвижимости.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда недвижимости или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidPropertyError`: если недвижимость содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о недвижимости и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения недвижимости по ежемесячной ставке, площади или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание недвижимости:
#    - Используйте `PropertyFactory` для создания недвижимости разных типов.
#    - Добавьте недвижимость в сервис с помощью метода `add_property`.
#
# 2. Управление данными:
#    - Редактируйте данные недвижимости через сеттеры.
#    - Удаляйте недвижимость из сервиса с помощью метода `remove_property`.
#
# 3. Анализ данных:
#    - Получите список всей недвижимости с помощью метода `get_all_properties`.
#    - Найдите недвижимость по адресу с помощью метода `search_by_address`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды недвижимости с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 20. Учет и управление сервисом проката велосипедов
#
# Разработайте программное обеспечение для учета и управления сервисом проката велосипедов. Программа должна предоставлять возможность создания записей о велосипедах, станциях проката, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Bicycle` (велосипед)**
#    - Создайте абстрактный класс `Bicycle`, который будет являться базовым для всех типов велосипедов.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех велосипедов: `bicycle_id` (идентификатор), `model` (модель), `type` (тип велосипеда), `hourly_rate` (стоимость аренды за час), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Велосипед: [model], Тип: [type]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения велосипедов по стоимости аренды или типу.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов велосипедов:
#      - `CityBike` (городской велосипед): добавьте атрибут `has_basket` (наличие корзины).
#      - `MountainBike` (горный велосипед): добавьте атрибут `suspension_type` (тип амортизации).
#      - `ElectricBike` (электровелосипед): добавьте атрибут `battery_life` (время работы батареи).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Городской велосипед: [model], Корзина: [has_basket]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `RentalStation`, который будет содержать информацию о станции проката:
#      - Атрибуты: `station_id` (идентификатор станции), `location` (местоположение), `bicycles` (список велосипедов), `capacity` (вместимость).
#      - Методы: `add_bicycle` (добавить велосипед), `remove_bicycle` (удалить велосипед), `get_available_bicycles` (получить список доступных велосипедов).
#    - Используйте **композицию**: добавьте атрибут `location_info` (информация о местоположении) через отдельный класс `Location`.
#    - Используйте **агрегацию**: станция может существовать без велосипедов, но велосипеды могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_bicycle`. Этот метод должен быть реализован для аренды велосипеда.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и велосипедами. Например, метод `log_action`, который записывает действия (например, "Велосипед [model] арендован").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш велосипед [model] готов к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `BicycleMeta`, который автоматически регистрирует все подклассы `Bicycle` в реестре. Это позволит динамически создавать экземпляры велосипедов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `BicycleFactory` с методом `create_bicycle`, который принимает тип велосипеда (например, `"city"`, `"mountain"`, `"electric"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания велосипедов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор станции может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`StationOperator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды велосипеда. Создайте базовый класс `RentalProcess` с методом `rent_bicycle`, который определяет общую структуру процесса:
#      - Проверка доступности велосипеда.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда велосипеда или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidBicycleError`: если велосипед содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о велосипедах и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения велосипедов по стоимости аренды, типу или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание велосипедов:
#    - Используйте `BicycleFactory` для создания велосипедов разных типов.
#    - Добавьте велосипеды на станцию проката с помощью метода `add_bicycle`.
#
# 2. Управление данными:
#    - Редактируйте данные велосипедов через сеттеры.
#    - Удаляйте велосипеды со станции с помощью метода `remove_bicycle`.
#
# 3. Анализ данных:
#    - Получите список всех велосипедов с помощью метода `get_all_bicycles`.
#    - Найдите велосипеды по модели с помощью метода `search_by_model`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды велосипеда с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 21. Учет и управление сервисом аренды электросамокатов
#
# Разработайте программное обеспечение для учета и управления сервисом аренды электросамокатов. Программа должна предоставлять возможность создания записей о самокатах, станциях аренды, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Scooter` (электросамокат)**
#    - Создайте абстрактный класс `Scooter`, который будет являться базовым для всех типов электросамокатов.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех самокатов: `scooter_id` (идентификатор), `model` (модель), `battery_level` (уровень заряда), `hourly_rate` (стоимость аренды за час), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Самокат: [model], Заряд: [battery_level]%").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения самокатов по стоимости аренды или уровню заряда.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов электросамокатов:
#      - `CityScooter` (городской самокат): добавьте атрибут `max_speed` (максимальная скорость).
#      - `OffRoadScooter` (внедорожный самокат): добавьте атрибут `tire_type` (тип шин).
#      - `FoldableScooter` (складной самокат): добавьте атрибут `weight` (вес).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Городской самокат: [model], Макс. скорость: [max_speed] км/ч").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `RentalStation`, который будет содержать информацию о станции аренды:
#      - Атрибуты: `station_id` (идентификатор станции), `location` (местоположение), `scooters` (список самокатов), `capacity` (вместимость).
#      - Методы: `add_scooter` (добавить самокат), `remove_scooter` (удалить самокат), `get_available_scooters` (получить список доступных самокатов).
#    - Используйте **композицию**: добавьте атрибут `location_info` (информация о местоположении) через отдельный класс `Location`.
#    - Используйте **агрегацию**: станция может существовать без самокатов, но самокаты могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_scooter`. Этот метод должен быть реализован для аренды самоката.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и самокатами. Например, метод `log_action`, который записывает действия (например, "Самокат [model] арендован").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш самокат [model] готов к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `ScooterMeta`, который автоматически регистрирует все подклассы `Scooter` в реестре. Это позволит динамически создавать экземпляры самокатов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `ScooterFactory` с методом `create_scooter`, который принимает тип самоката (например, `"city"`, `"off_road"`, `"foldable"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания самокатов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор станции может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`StationOperator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды самоката. Создайте базовый класс `RentalProcess` с методом `rent_scooter`, который определяет общую структуру процесса:
#      - Проверка доступности самоката.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда самоката или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidScooterError`: если самокат содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о самокатах и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения самокатов по стоимости аренды, уровню заряда или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание самокатов:
#    - Используйте `ScooterFactory` для создания самокатов разных типов.
#    - Добавьте самокаты на станцию аренды с помощью метода `add_scooter`.
#
# 2. Управление данными:
#    - Редактируйте данные самокатов через сеттеры.
#    - Удаляйте самокаты со станции с помощью метода `remove_scooter`.
#
# 3. Анализ данных:
#    - Получите список всех самокатов с помощью метода `get_all_scooters`.
#    - Найдите самокаты по модели с помощью метода `search_by_model`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды самоката с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 22. Учет и управление сервисом аренды электромобилей
#
# Разработайте программное обеспечение для учета и управления сервисом аренды электромобилей. Программа должна предоставлять возможность создания записей о электромобилях, станциях зарядки, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `ElectricCar` (электромобиль)**
#    - Создайте абстрактный класс `ElectricCar`, который будет являться базовым для всех типов электромобилей.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех электромобилей: `car_id` (идентификатор), `model` (модель), `battery_level` (уровень заряда), `hourly_rate` (стоимость аренды за час), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Электромобиль: [model], Заряд: [battery_level]%").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения электромобилей по стоимости аренды или уровню заряда.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов электромобилей:
#      - `CityCar` (городской электромобиль): добавьте атрибут `max_speed` (максимальная скорость).
#      - `SUV` (внедорожный электромобиль): добавьте атрибут `towing_capacity` (грузоподъемность).
#      - `LuxuryCar` (люксовый электромобиль): добавьте атрибут `premium_features` (список премиальных функций).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Городской электромобиль: [model], Макс. скорость: [max_speed] км/ч").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `ChargingStation`, который будет содержать информацию о станции зарядки:
#      - Атрибуты: `station_id` (идентификатор станции), `location` (местоположение), `cars` (список электромобилей), `capacity` (вместимость).
#      - Методы: `add_car` (добавить электромобиль), `remove_car` (удалить электромобиль), `get_available_cars` (получить список доступных электромобилей).
#    - Используйте **композицию**: добавьте атрибут `location_info` (информация о местоположении) через отдельный класс `Location`.
#    - Используйте **агрегацию**: станция может существовать без электромобилей, но электромобили могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_car`. Этот метод должен быть реализован для аренды электромобиля.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и электромобилями. Например, метод `log_action`, который записывает действия (например, "Электромобиль [model] арендован").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш электромобиль [model] готов к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `ElectricCarMeta`, который автоматически регистрирует все подклассы `ElectricCar` в реестре. Это позволит динамически создавать экземпляры электромобилей по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `ElectricCarFactory` с методом `create_car`, который принимает тип электромобиля (например, `"city"`, `"suv"`, `"luxury"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания электромобилей в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор станции может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`StationOperator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды электромобиля. Создайте базовый класс `RentalProcess` с методом `rent_car`, который определяет общую структуру процесса:
#      - Проверка доступности электромобиля.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда электромобиля или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidCarError`: если электромобиль содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об электромобилях и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения электромобилей по стоимости аренды, уровню заряда или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание электромобилей:
#    - Используйте `ElectricCarFactory` для создания электромобилей разных типов.
#    - Добавьте электромобили на станцию зарядки с помощью метода `add_car`.
#
# 2. Управление данными:
#    - Редактируйте данные электромобилей через сеттеры.
#    - Удаляйте электромобили со станции с помощью метода `remove_car`.
#
# 3. Анализ данных:
#    - Получите список всех электромобилей с помощью метода `get_all_cars`.
#    - Найдите электромобили по модели с помощью метода `search_by_model`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды электромобиля с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 23. Учет и управление сервисом аренды лодок
#
# Разработайте программное обеспечение для учета и управления сервисом аренды лодок. Программа должна предоставлять возможность создания записей о лодках, причалах, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Boat` (лодка)**
#    - Создайте абстрактный класс `Boat`, который будет являться базовым для всех типов лодок.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех лодок: `boat_id` (идентификатор), `model` (модель), `capacity` (вместимость), `hourly_rate` (стоимость аренды за час), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Лодка: [model], Вместимость: [capacity] человек").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения лодок по стоимости аренды или вместимости.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов лодок:
#      - `Rowboat` (весельная лодка): добавьте атрибут `number_of_oars` (количество весел).
#      - `Motorboat` (моторная лодка): добавьте атрибут `engine_power` (мощность двигателя).
#      - `Yacht` (яхта): добавьте атрибут `luxury_level` (уровень роскоши).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Моторная лодка: [model], Мощность двигателя: [engine_power] л.с.").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Dock`, который будет содержать информацию о причале:
#      - Атрибуты: `dock_id` (идентификатор причала), `location` (местоположение), `boats` (список лодок), `capacity` (вместимость).
#      - Методы: `add_boat` (добавить лодку), `remove_boat` (удалить лодку), `get_available_boats` (получить список доступных лодок).
#    - Используйте **композицию**: добавьте атрибут `location_info` (информация о местоположении) через отдельный класс `Location`.
#    - Используйте **агрегацию**: причал может существовать без лодок, но лодки могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_boat`. Этот метод должен быть реализован для аренды лодки.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и лодками. Например, метод `log_action`, который записывает действия (например, "Лодка [model] арендована").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваша лодка [model] готова к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `BoatMeta`, который автоматически регистрирует все подклассы `Boat` в реестре. Это позволит динамически создавать экземпляры лодок по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `BoatFactory` с методом `create_boat`, который принимает тип лодки (например, `"rowboat"`, `"motorboat"`, `"yacht"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания лодок в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор причала может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`DockOperator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды лодки. Создайте базовый класс `RentalProcess` с методом `rent_boat`, который определяет общую структуру процесса:
#      - Проверка доступности лодки.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда лодки или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidBoatError`: если лодка содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о лодках и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения лодок по стоимости аренды, вместимости или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание лодок:
#    - Используйте `BoatFactory` для создания лодок разных типов.
#    - Добавьте лодки на причал с помощью метода `add_boat`.
#
# 2. Управление данными:
#    - Редактируйте данные лодок через сеттеры.
#    - Удаляйте лодки с причала с помощью метода `remove_boat`.
#
# 3. Анализ данных:
#    - Получите список всех лодок с помощью метода `get_all_boats`.
#    - Найдите лодки по модели с помощью метода `search_by_model`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды лодки с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 24. Учет и управление сервисом аренды спортивного инвентаря
#
# Разработайте программное обеспечение для учета и управления сервисом аренды спортивного инвентаря. Программа должна предоставлять возможность создания записей о спортивном инвентаре, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `SportEquipment` (спортивный инвентарь)**
#    - Создайте абстрактный класс `SportEquipment`, который будет являться базовым для всех типов спортивного инвентаря.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех типов инвентаря: `equipment_id` (идентификатор), `name` (название), `condition` (состояние), `hourly_rate` (стоимость аренды за час), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Инвентарь: [name], Состояние: [condition]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения инвентаря по стоимости аренды или состоянию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов спортивного инвентаря:
#      - `Bicycle` (велосипед): добавьте атрибут `type` (тип велосипеда).
#      - `Skis` (лыжи): добавьте атрибут `length` (длина).
#      - `TennisRacket` (теннисная ракетка): добавьте атрибут `string_tension` (натяжение струн).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Велосипед: [name], Тип: [type]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `equipment` (спортивный инвентарь), `start_time` (время начала аренды), `end_time` (время окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_extra` (добавить дополнительную услугу), `remove_extra` (удалить дополнительную услугу), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без дополнительных услуг, но услуги могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_equipment`. Этот метод должен быть реализован для аренды спортивного инвентаря.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и инвентарем. Например, метод `log_action`, который записывает действия (например, "Инвентарь [name] арендован").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш инвентарь [name] готов к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `EquipmentMeta`, который автоматически регистрирует все подклассы `SportEquipment` в реестре. Это позволит динамически создавать экземпляры инвентаря по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `EquipmentFactory` с методом `create_equipment`, который принимает тип инвентаря (например, `"bicycle"`, `"skis"`, `"tennis_racket"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания инвентаря в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Operator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды инвентаря. Создайте базовый класс `RentalProcess` с методом `rent_equipment`, который определяет общую структуру процесса:
#      - Проверка доступности инвентаря.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда инвентаря или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidEquipmentError`: если инвентарь содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об инвентаре и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения инвентаря по стоимости аренды, состоянию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание инвентаря:
#    - Используйте `EquipmentFactory` для создания инвентаря разных типов.
#    - Добавьте инвентарь в сервис с помощью метода `add_equipment`.
#
# 2. Управление данными:
#    - Редактируйте данные инвентаря через сеттеры.
#    - Удаляйте инвентарь из сервиса с помощью метода `remove_equipment`.
#
# 3. Анализ данных:
#    - Получите список всего инвентаря с помощью метода `get_all_equipment`.
#    - Найдите инвентарь по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды инвентаря с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 25. Учет и управление сервисом аренды музыкальных инструментов
#
# Разработайте программное обеспечение для учета и управления сервисом аренды музыкальных инструментов. Программа должна предоставлять возможность создания записей о музыкальных инструментах, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `MusicalInstrument` (музыкальный инструмент)**
#    - Создайте абстрактный класс `MusicalInstrument`, который будет являться базовым для всех типов музыкальных инструментов.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех инструментов: `instrument_id` (идентификатор), `name` (название), `condition` (состояние), `daily_rate` (стоимость аренды за день), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Инструмент: [name], Состояние: [condition]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения инструментов по стоимости аренды или состоянию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов музыкальных инструментов:
#      - `Guitar` (гитара): добавьте атрибут `number_of_strings` (количество струн).
#      - `Piano` (пианино): добавьте атрибут `key_count` (количество клавиш).
#      - `Violin` (скрипка): добавьте атрибут `bow_included` (наличие смычка).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Гитара: [name], Струн: [number_of_strings]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `instrument` (музыкальный инструмент), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_accessory` (добавить аксессуар), `remove_accessory` (удалить аксессуар), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без аксессуаров, но аксессуары могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_instrument`. Этот метод должен быть реализован для аренды музыкального инструмента.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и инструментами. Например, метод `log_action`, который записывает действия (например, "Инструмент [name] арендован").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваш инструмент [name] готов к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `InstrumentMeta`, который автоматически регистрирует все подклассы `MusicalInstrument` в реестре. Это позволит динамически создавать экземпляры инструментов по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `InstrumentFactory` с методом `create_instrument`, который принимает тип инструмента (например, `"guitar"`, `"piano"`, `"violin"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания инструментов в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Operator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды инструмента. Создайте базовый класс `RentalProcess` с методом `rent_instrument`, который определяет общую структуру процесса:
#      - Проверка доступности инструмента.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда инструмента или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidInstrumentError`: если инструмент содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об инструментах и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения инструментов по стоимости аренды, состоянию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание инструментов:
#    - Используйте `InstrumentFactory` для создания инструментов разных типов.
#    - Добавьте инструменты в сервис с помощью метода `add_instrument`.
#
# 2. Управление данными:
#    - Редактируйте данные инструментов через сеттеры.
#    - Удаляйте инструменты из сервиса с помощью метода `remove_instrument`.
#
# 3. Анализ данных:
#    - Получите список всех инструментов с помощью метода `get_all_instruments`.
#    - Найдите инструменты по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды инструмента с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 26. Учет и управление сервисом аренды фото- и видеооборудования
#
# Разработайте программное обеспечение для учета и управления сервисом аренды фото- и видеооборудования. Программа должна предоставлять возможность создания записей о камерах, объективах, аксессуарах, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `Equipment` (оборудование)**
#    - Создайте абстрактный класс `Equipment`, который будет являться базовым для всех типов оборудования.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех типов оборудования: `equipment_id` (идентификатор), `name` (название), `condition` (состояние), `daily_rate` (стоимость аренды за день), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Оборудование: [name], Состояние: [condition]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения оборудования по стоимости аренды или состоянию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов оборудования:
#      - `Camera` (камера): добавьте атрибут `sensor_type` (тип сенсора).
#      - `Lens` (объектив): добавьте атрибут `focal_length` (фокусное расстояние).
#      - `Accessory` (аксессуар): добавьте атрибут `compatibility` (совместимость с оборудованием).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Камера: [name], Тип сенсора: [sensor_type]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `equipment` (оборудование), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_accessory` (добавить аксессуар), `remove_accessory` (удалить аксессуар), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без аксессуаров, но аксессуары могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_equipment`. Этот метод должен быть реализован для аренды оборудования.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и оборудованием. Например, метод `log_action`, который записывает действия (например, "Оборудование [name] арендовано").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваше оборудование [name] готово к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `EquipmentMeta`, который автоматически регистрирует все подклассы `Equipment` в реестре. Это позволит динамически создавать экземпляры оборудования по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `EquipmentFactory` с методом `create_equipment`, который принимает тип оборудования (например, `"camera"`, `"lens"`, `"accessory"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания оборудования в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Operator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды оборудования. Создайте базовый класс `RentalProcess` с методом `rent_equipment`, который определяет общую структуру процесса:
#      - Проверка доступности оборудования.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда оборудования или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidEquipmentError`: если оборудование содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об оборудовании и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения оборудования по стоимости аренды, состоянию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание оборудования:
#    - Используйте `EquipmentFactory` для создания оборудования разных типов.
#    - Добавьте оборудование в сервис с помощью метода `add_equipment`.
#
# 2. Управление данными:
#    - Редактируйте данные оборудования через сеттеры.
#    - Удаляйте оборудование из сервиса с помощью метода `remove_equipment`.
#
# 3. Анализ данных:
#    - Получите список всего оборудования с помощью метода `get_all_equipment`.
#    - Найдите оборудование по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды оборудования с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 27. Учет и управление сервисом аренды строительного оборудования
#
# Разработайте программное обеспечение для учета и управления сервисом аренды строительного оборудования. Программа должна предоставлять возможность создания записей о строительном оборудовании, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `ConstructionEquipment` (строительное оборудование)**
#    - Создайте абстрактный класс `ConstructionEquipment`, который будет являться базовым для всех типов строительного оборудования.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех типов оборудования: `equipment_id` (идентификатор), `name` (название), `condition` (состояние), `daily_rate` (стоимость аренды за день), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Оборудование: [name], Состояние: [condition]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения оборудования по стоимости аренды или состоянию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов строительного оборудования:
#      - `Excavator` (экскаватор): добавьте атрибут `bucket_capacity` (емкость ковша).
#      - `Crane` (кран): добавьте атрибут `lifting_capacity` (грузоподъемность).
#      - `ConcreteMixer` (бетономешалка): добавьте атрибут `mixer_capacity` (емкость барабана).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Экскаватор: [name], Емкость ковша: [bucket_capacity]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `equipment` (строительное оборудование), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_accessory` (добавить аксессуар), `remove_accessory` (удалить аксессуар), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без аксессуаров, но аксессуары могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_equipment`. Этот метод должен быть реализован для аренды строительного оборудования.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и оборудованием. Например, метод `log_action`, который записывает действия (например, "Оборудование [name] арендовано").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваше оборудование [name] готово к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `EquipmentMeta`, который автоматически регистрирует все подклассы `ConstructionEquipment` в реестре. Это позволит динамически создавать экземпляры оборудования по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `EquipmentFactory` с методом `create_equipment`, который принимает тип оборудования (например, `"excavator"`, `"crane"`, `"concrete_mixer"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания оборудования в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Operator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды оборудования. Создайте базовый класс `RentalProcess` с методом `rent_equipment`, который определяет общую структуру процесса:
#      - Проверка доступности оборудования.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда оборудования или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidEquipmentError`: если оборудование содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об оборудовании и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения оборудования по стоимости аренды, состоянию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание оборудования:
#    - Используйте `EquipmentFactory` для создания оборудования разных типов.
#    - Добавьте оборудование в сервис с помощью метода `add_equipment`.
#
# 2. Управление данными:
#    - Редактируйте данные оборудования через сеттеры.
#    - Удаляйте оборудование из сервиса с помощью метода `remove_equipment`.
#
# 3. Анализ данных:
#    - Получите список всего оборудования с помощью метода `get_all_equipment`.
#    - Найдите оборудование по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды оборудования с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 28. Учет и управление сервисом аренды медицинского оборудования
#
# Разработайте программное обеспечение для учета и управления сервисом аренды медицинского оборудования. Программа должна предоставлять возможность создания записей о медицинском оборудовании, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `MedicalEquipment` (медицинское оборудование)**
#    - Создайте абстрактный класс `MedicalEquipment`, который будет являться базовым для всех типов медицинского оборудования.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех типов оборудования: `equipment_id` (идентификатор), `name` (название), `condition` (состояние), `daily_rate` (стоимость аренды за день), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Оборудование: [name], Состояние: [condition]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения оборудования по стоимости аренды или состоянию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов медицинского оборудования:
#      - `Ventilator` (вентилятор): добавьте атрибут `ventilation_mode` (режим вентиляции).
#      - `Defibrillator` (дефибриллятор): добавьте атрибут `energy_level` (уровень энергии).
#      - `UltrasoundMachine` (ультразвуковой аппарат): добавьте атрибут `probe_type` (тип датчика).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Вентилятор: [name], Режим вентиляции: [ventilation_mode]").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `equipment` (медицинское оборудование), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_accessory` (добавить аксессуар), `remove_accessory` (удалить аксессуар), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без аксессуаров, но аксессуары могут быть добавлены позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_equipment`. Этот метод должен быть реализован для аренды медицинского оборудования.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и оборудованием. Например, метод `log_action`, который записывает действия (например, "Оборудование [name] арендовано").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваше оборудование [name] готово к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `EquipmentMeta`, который автоматически регистрирует все подклассы `MedicalEquipment` в реестре. Это позволит динамически создавать экземпляры оборудования по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `EquipmentFactory` с методом `create_equipment`, который принимает тип оборудования (например, `"ventilator"`, `"defibrillator"`, `"ultrasound_machine"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания оборудования в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Operator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды оборудования. Создайте базовый класс `RentalProcess` с методом `rent_equipment`, который определяет общую структуру процесса:
#      - Проверка доступности оборудования.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда оборудования или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidEquipmentError`: если оборудование содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об оборудовании и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения оборудования по стоимости аренды, состоянию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание оборудования:
#    - Используйте `EquipmentFactory` для создания оборудования разных типов.
#    - Добавьте оборудование в сервис с помощью метода `add_equipment`.
#
# 2. Управление данными:
#    - Редактируйте данные оборудования через сеттеры.
#    - Удаляйте оборудование из сервиса с помощью метода `remove_equipment`.
#
# 3. Анализ данных:
#    - Получите список всего оборудования с помощью метода `get_all_equipment`.
#    - Найдите оборудование по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды оборудования с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 29. Учет и управление сервисом аренды сельскохозяйственной техники
#
# Разработайте программное обеспечение для учета и управления сервисом аренды сельскохозяйственной техники. Программа должна предоставлять возможность создания записей о сельскохозяйственной технике, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `AgriculturalEquipment` (сельскохозяйственная техника)**
#    - Создайте абстрактный класс `AgriculturalEquipment`, который будет являться базовым для всех типов сельскохозяйственной техники.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех типов техники: `equipment_id` (идентификатор), `name` (название), `condition` (состояние), `daily_rate` (стоимость аренды за день), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Техника: [name], Состояние: [condition]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения техники по стоимости аренды или состоянию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов сельскохозяйственной техники:
#      - `Tractor` (трактор): добавьте атрибут `horsepower` (мощность двигателя).
#      - `Harvester` (комбайн): добавьте атрибут `grain_capacity` (емкость бункера).
#      - `Seeder` (сеялка): добавьте атрибут `seed_capacity` (емкость семенного бункера).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Трактор: [name], Мощность: [horsepower] л.с.").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `equipment` (сельскохозяйственная техника), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_attachment` (добавить навесное оборудование), `remove_attachment` (удалить навесное оборудование), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без навесного оборудования, но навесное оборудование может быть добавлено позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_equipment`. Этот метод должен быть реализован для аренды сельскохозяйственной техники.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и техникой. Например, метод `log_action`, который записывает действия (например, "Техника [name] арендована").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваша техника [name] готова к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `EquipmentMeta`, который автоматически регистрирует все подклассы `AgriculturalEquipment` в реестре. Это позволит динамически создавать экземпляры техники по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `EquipmentFactory` с методом `create_equipment`, который принимает тип техники (например, `"tractor"`, `"harvester"`, `"seeder"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания техники в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Operator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды техники. Создайте базовый класс `RentalProcess` с методом `rent_equipment`, который определяет общую структуру процесса:
#      - Проверка доступности техники.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда техники или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidEquipmentError`: если техника содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о технике и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения техники по стоимости аренды, состоянию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание техники:
#    - Используйте `EquipmentFactory` для создания техники разных типов.
#    - Добавьте технику в сервис с помощью метода `add_equipment`.
#
# 2. Управление данными:
#    - Редактируйте данные техники через сеттеры.
#    - Удаляйте технику из сервиса с помощью метода `remove_equipment`.
#
# 3. Анализ данных:
#    - Получите список всей техники с помощью метода `get_all_equipment`.
#    - Найдите технику по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды техники с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 30. Учет и управление сервисом аренды промышленного оборудования
#
# Разработайте программное обеспечение для учета и управления сервисом аренды промышленного оборудования. Программа должна предоставлять возможность создания записей о промышленном оборудовании, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `IndustrialEquipment` (промышленное оборудование)**
#    - Создайте абстрактный класс `IndustrialEquipment`, который будет являться базовым для всех типов промышленного оборудования.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех типов оборудования: `equipment_id` (идентификатор), `name` (название), `condition` (состояние), `daily_rate` (стоимость аренды за день), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Оборудование: [name], Состояние: [condition]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения оборудования по стоимости аренды или состоянию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов промышленного оборудования:
#      - `Forklift` (погрузчик): добавьте атрибут `lifting_capacity` (грузоподъемность).
#      - `Crane` (кран): добавьте атрибут `boom_length` (длина стрелы).
#      - `Compressor` (компрессор): добавьте атрибут `air_flow` (производительность по воздуху).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Погрузчик: [name], Грузоподъемность: [lifting_capacity] кг").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `equipment` (промышленное оборудование), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_attachment` (добавить навесное оборудование), `remove_attachment` (удалить навесное оборудование), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без навесного оборудования, но навесное оборудование может быть добавлено позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_equipment`. Этот метод должен быть реализован для аренды промышленного оборудования.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и оборудованием. Например, метод `log_action`, который записывает действия (например, "Оборудование [name] арендовано").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваше оборудование [name] готово к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `EquipmentMeta`, который автоматически регистрирует все подклассы `IndustrialEquipment` в реестре. Это позволит динамически создавать экземпляры оборудования по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `EquipmentFactory` с методом `create_equipment`, который принимает тип оборудования (например, `"forklift"`, `"crane"`, `"compressor"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания оборудования в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Operator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды оборудования. Создайте базовый класс `RentalProcess` с методом `rent_equipment`, который определяет общую структуру процесса:
#      - Проверка доступности оборудования.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда оборудования или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidEquipmentError`: если оборудование содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных об оборудовании и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения оборудования по стоимости аренды, состоянию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание оборудования:
#    - Используйте `EquipmentFactory` для создания оборудования разных типов.
#    - Добавьте оборудование в сервис с помощью метода `add_equipment`.
#
# 2. Управление данными:
#    - Редактируйте данные оборудования через сеттеры.
#    - Удаляйте оборудование из сервиса с помощью метода `remove_equipment`.
#
# 3. Анализ данных:
#    - Получите список всего оборудования с помощью метода `get_all_equipment`.
#    - Найдите оборудование по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды оборудования с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.

# %% [markdown]
# # Вариант 31. Учет и управление сервисом аренды строительной техники
#
# Разработайте программное обеспечение для учета и управления сервисом аренды строительной техники. Программа должна предоставлять возможность создания записей о строительной технике, клиентах, аренде и других данных. Также программа должна поддерживать выполнение различных операций с данными, таких как добавление, редактирование, удаление, поиск и анализ.
#
#
#
# ### Основные требования к реализации
#
# #### 1. **Абстрактный класс `ConstructionEquipment` (строительная техника)**
#    - Создайте абстрактный класс `ConstructionEquipment`, который будет являться базовым для всех типов строительной техники.
#    - В классе определите:
#      - Абстрактный метод `calculate_rental_cost`, который должен быть реализован в каждом подклассе.
#      - Общие атрибуты для всех типов техники: `equipment_id` (идентификатор), `name` (название), `condition` (состояние), `daily_rate` (стоимость аренды за день), `is_available` (доступность).
#      - Метод `__str__`, возвращающий строковое представление объекта (например, "Техника: [name], Состояние: [condition]").
#      - Методы сравнения (`__lt__`, `__gt__`) для сравнения техники по стоимости аренды или состоянию.
#    - Используйте инкапсуляцию: сделайте атрибуты приватными и предоставьте доступ к ним через геттеры и сеттеры с аннотациями типов.
#
# #### 2. **Наследование**
#    - Создайте подклассы для различных типов строительной техники:
#      - `Excavator` (экскаватор): добавьте атрибут `bucket_capacity` (емкость ковша).
#      - `Bulldozer` (бульдозер): добавьте атрибут `blade_width` (ширина отвала).
#      - `ConcreteMixer` (бетономешалка): добавьте атрибут `mixer_capacity` (емкость барабана).
#    - В каждом подклассе переопределите метод `calculate_rental_cost` для расчета стоимости аренды с учетом дополнительных факторов (например, скидки на длительную аренду).
#    - Переопределите метод `__str__` для вывода дополнительной информации (например, "Экскаватор: [name], Емкость ковша: [bucket_capacity] м³").
#
# #### 3. **Композиция и агрегация**
#    - Создайте класс `Rental`, который будет содержать информацию об аренде:
#      - Атрибуты: `rental_id` (идентификатор аренды), `customer` (клиент), `equipment` (строительная техника), `start_date` (дата начала аренды), `end_date` (дата окончания аренды), `total_cost` (общая стоимость).
#      - Методы: `add_attachment` (добавить навесное оборудование), `remove_attachment` (удалить навесное оборудование), `calculate_total` (рассчитать общую стоимость).
#    - Используйте **композицию**: добавьте атрибут `customer_info` (информация о клиенте) через отдельный класс `Customer`.
#    - Используйте **агрегацию**: аренда может существовать без навесного оборудования, но навесное оборудование может быть добавлено позже.
#
# #### 4. **Интерфейсы для работы с сервисом**
#    - Создайте интерфейс `Rentable`, который определяет метод `rent_equipment`. Этот метод должен быть реализован для аренды строительной техники.
#    - Добавьте второй интерфейс `Reportable`, который определяет метод `generate_report`. Этот метод должен быть реализован для генерации отчетов об аренде (например, "Отчет по аренде: [данные]").
#
# #### 5. **Миксины**
#    - Создайте миксин `LoggingMixin`, который добавляет функциональность логирования действий с арендой и техникой. Например, метод `log_action`, который записывает действия (например, "Техника [name] арендована").
#    - Создайте второй миксин `NotificationMixin`, который добавляет функциональность отправки уведомлений. Например, метод `send_notification`, который отправляет уведомления (например, "Ваша техника [name] готова к выдаче" или "Аренда отменена").
#    - Используйте оба миксина в подклассах для демонстрации множественного наследования.
#
# #### 6. **Метаклассы**
#    - Реализуйте метакласс `EquipmentMeta`, который автоматически регистрирует все подклассы `ConstructionEquipment` в реестре. Это позволит динамически создавать экземпляры техники по имени типа.
#
# #### 7. **Фабричные методы**
#    - Создайте класс `EquipmentFactory` с методом `create_equipment`, который принимает тип техники (например, `"excavator"`, `"bulldozer"`, `"concrete_mixer"`) и создает соответствующий экземпляр класса.
#    - Используйте этот метод для создания техники в программе.
#
# #### 8. **Цепочка обязанностей (Chain of Responsibility)**
#    - Реализуйте паттерн "Цепочка обязанностей" для обработки запросов на изменение аренды. Например:
#      - Оператор может одобрить изменение, если оно незначительное.
#      - Менеджер может одобрить изменение, если оно требует пересмотра стоимости.
#      - Администратор может одобрить любое изменение.
#    - Создайте цепочку обработчиков (`Operator`, `Manager`, `Admin`), которая последовательно передает запросы между звеньями.
#
# #### 9. **Шаблонный метод (Template Method)**
#    - Реализуйте шаблонный метод для стандартизации процесса аренды техники. Создайте базовый класс `RentalProcess` с методом `rent_equipment`, который определяет общую структуру процесса:
#      - Проверка доступности техники.
#      - Оформление аренды.
#      - Подтверждение аренды.
#    - Подклассы (`OnlineRentalProcess`, `OfflineRentalProcess`) должны реализовывать конкретные шаги процесса.
#
# #### 10. **Декоратор для проверки прав доступа**
#    - Создайте декоратор `check_permissions`, который проверяет права доступа пользователя перед выполнением определенных действий (например, аренда техники или изменение аренды). Если у пользователя нет прав, выбрасывайте исключение `PermissionDeniedError`.
#
# #### 11. **Исключения**
#    - Создайте пользовательские исключения для обработки ошибок:
#      - `InvalidEquipmentError`: если техника содержит некорректные данные.
#      - `PermissionDeniedError`: если у пользователя нет прав доступа.
#      - `RentalNotFoundError`: если аренда не найдена.
#
# #### 12. **Сериализация и десериализация**
#    - Реализуйте возможность сохранения и загрузки данных о технике и аренде в файл (например, в формате JSON).
#    - Добавьте методы `to_dict` и `from_dict` для преобразования объектов в словари и обратно.
#
# #### 13. **Методы сравнения**
#    - Реализуйте методы `__eq__`, `__lt__`, `__gt__` для сравнения техники по стоимости аренды, состоянию или другим критериям.
#
# #### 14. **Логирование и документация**
#    - Настройте систему логирования с использованием библиотеки `logging`. Логи должны записываться в файл и в консоль.
#    - Добавьте docstrings для всех методов и классов.
#
#
#
# ### Пример использования программы
#
# 1. Создание техники:
#    - Используйте `EquipmentFactory` для создания техники разных типов.
#    - Добавьте технику в сервис с помощью метода `add_equipment`.
#
# 2. Управление данными:
#    - Редактируйте данные техники через сеттеры.
#    - Удаляйте технику из сервиса с помощью метода `remove_equipment`.
#
# 3. Анализ данных:
#    - Получите список всей техники с помощью метода `get_all_equipment`.
#    - Найдите технику по названию с помощью метода `search_by_name`.
#
# 4. Логирование и уведомления:
#    - Используйте миксины `LoggingMixin` и `NotificationMixin` для записи действий и отправки уведомлений.
#
# 5. Обработка исключений:
#    - Обрабатывайте пользовательские исключения при попытке аренды техники с некорректными данными или при отсутствии прав доступа.
#
#
#
# ### Заключение
#
# Данная программа демонстрирует применение объектно-ориентированного программирования, включая наследование, композицию, агрегацию, интерфейсы, миксины, метаклассы, фабричные методы, паттерны проектирования (цепочка обязанностей, шаблонный метод) и другие концепции. Она также включает функциональность для логирования, обработки исключений и сериализации данных.
