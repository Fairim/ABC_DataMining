# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ABC_DataMining/blob/main/Python/Dictionary_set_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задачи для всех**

# %% [markdown]
# #Dictionary
#
# 1. **Подсчет частоты слов**: Напишите функцию, которая принимает строку и возвращает словарь, где ключи — это слова, а значения — их частота в строке.
#
# 2. **Инвертирование словаря**: Напишите функцию, которая принимает словарь и возвращает новый словарь, где ключи и значения поменяны местами. Если значения не уникальны, объедините ключи в список.
#
# 3. **Слияние словарей**: Напишите функцию, которая принимает два словаря и возвращает новый словарь, содержащий все ключи из обоих словарей. Если ключи совпадают, значения должны быть суммированы.
#
# 4. **Фильтрация по значению**: Напишите функцию, которая принимает словарь и пороговое значение, и возвращает новый словарь, содержащий только те пары ключ-значение, где значение больше порогового.
#
# 5. **Максимальное значение**: Напишите функцию, которая находит ключ с максимальным значением в словаре.
#
# 6. **Минимальное значение**: Напишите функцию, которая находит ключ с минимальным значением в словаре.
#
# 7. **Удаление ключей**: Напишите функцию, которая принимает словарь и список ключей, и удаляет из словаря все указанные ключи.
#
# 8. **Группировка по длине ключей**: Напишите функцию, которая группирует ключи словаря по их длине и возвращает словарь, где ключи — это длины, а значения — списки ключей соответствующей длины.
#
# 9. **Поиск ключей по значению**: Напишите функцию, которая принимает словарь и значение, и возвращает список всех ключей, связанных с этим значением.
#
# 10. **Объединение значений**: Напишите функцию, которая принимает два словаря и объединяет их значения в списки для каждого ключа.
#
# 11. **Уникальные значения**: Напишите функцию, которая возвращает множество уникальных значений из словаря.
#
# 12. **Сортировка по ключам**: Напишите функцию, которая сортирует словарь по ключам и возвращает новый отсортированный словарь.
#
# 13. **Сортировка по значениям**: Напишите функцию, которая сортирует словарь по значениям и возвращает новый отсортированный словарь.
#
# 14. **Вложенный словарь**: Напишите функцию, которая создает вложенный словарь, где первый уровень ключей — это буквы алфавита, а второй уровень — числа от 1 до 10.
#
# 15. **Сумма значений**: Напишите функцию, которая вычисляет сумму всех значений в словаре.
#
# 16. **Произведение значений**: Напишите функцию, которая вычисляет произведение всех значений в словаре.
#
# 17. **Ключи с четными значениями**: Напишите функцию, которая возвращает список ключей, связанных с четными значениями.
#
# 18. **Ключи с нечетными значениями**: Напишите функцию, которая возвращает список ключей, связанных с нечетными значениями.
#
# 19. **Удаление дубликатов**: Напишите функцию, которая удаляет дубликаты значений из словаря, оставляя только первое вхождение.
#
# 20. **Пересечение словарей**: Напишите функцию, которая принимает два словаря и возвращает новый словарь, содержащий только те пары ключ-значение, которые присутствуют в обоих словарях.
#
# 21. **Разность словарей**: Напишите функцию, которая принимает два словаря и возвращает новый словарь, содержащий только те пары ключ-значение, которые присутствуют в первом словаре, но отсутствуют во втором.
#
# 22. **Обновление значений**: Напишите функцию, которая увеличивает все значения в словаре на заданное число.
#
# 23. **Преобразование значений**: Напишите функцию, которая преобразует все значения в словаре в строки.
#
# 24. **Ключи с максимальной длиной**: Напишите функцию, которая находит ключ с максимальной длиной в словаре.
#
# 25. **Ключи с минимальной длиной**: Напишите функцию, которая находит ключ с минимальной длиной в словаре.
#
# 26. **Группировка по типам значений**: Напишите функцию, которая группирует ключи словаря по типам их значений (например, int, str, list).
#
# 27. **Среднее значение**: Напишите функцию, которая вычисляет среднее значение всех числовых значений в словаре.
#
# 28. **Частота значений**: Напишите функцию, которая подсчитывает частоту каждого значения в словаре.
#
# 29. **Ключи с палиндромами**: Напишите функцию, которая возвращает список ключей, связанных со значениями-палиндромами.
#
# 30. **Глубокая копия словаря**: Напишите функцию, которая создает глубокую копию словаря, включая все вложенные структуры данных.

# %% [markdown]
# ## Множества

# %% [markdown]
# 1. **Создание множества из списка**: Напишите функцию, которая принимает список и возвращает множество, содержащее уникальные элементы списка.
#
# 2. **Удаление дубликатов**: Напишите функцию, которая удаляет дубликаты из списка с помощью множества и возвращает новый список.
#
# 3. **Пересечение множеств**: Напишите функцию, которая принимает два множества и возвращает их пересечение.
#
# 4. **Объединение множеств**: Напишите функцию, которая принимает два множества и возвращает их объединение.
#
# 5. **Разность множеств**: Напишите функцию, которая принимает два множества и возвращает разность первого множества и второго.
#
# 6. **Симметрическая разность**: Напишите функцию, которая принимает два множества и возвращает их симметрическую разность.
#
# 7. **Проверка подмножества**: Напишите функцию, которая проверяет, является ли одно множество подмножеством другого.
#
# 8. **Проверка надмножества**: Напишите функцию, которая проверяет, является ли одно множество надмножеством другого.
#
# 9. **Добавление элементов**: Напишите функцию, которая добавляет все элементы из списка в множество.
#
# 10. **Удаление элементов**: Напишите функцию, которая удаляет из множества все элементы, присутствующие в списке.
#
# 11. **Элементы, встречающиеся только в одном множестве**: Напишите функцию, которая находит элементы, которые есть только в одном из двух множеств.
#
# 12. **Общие элементы**: Напишите функцию, которая находит общие элементы двух списков с помощью множеств.
#
# 13. **Уникальные элементы**: Напишите функцию, которая находит элементы, которые есть только в одном из двух списков.
#
# 14. **Проверка на пустоту**: Напишите функцию, которая проверяет, является ли множество пустым.
#
# 15. **Количество уникальных элементов**: Напишите функцию, которая возвращает количество уникальных элементов в списке с помощью множества.
#
# 16. **Максимальный элемент**: Напишите функцию, которая находит максимальный элемент в множестве.
#
# 17. **Минимальный элемент**: Напишите функцию, которая находит минимальный элемент в множестве.
#
# 18. **Сортировка множества**: Напишите функцию, которая преобразует множество в отсортированный список.
#
# 19. **Частота элементов**: Напишите функцию, которая подсчитывает частоту каждого элемента в списке с помощью множества.
#
# 20. **Объединение нескольких множеств**: Напишите функцию, которая принимает список множеств и возвращает их объединение.
#
# 21. **Пересечение нескольких множеств**: Напишите функцию, которая принимает список множеств и возвращает их пересечение.
#
# 22. **Разбиение множества**: Напишите функцию, которая разбивает множество на два: одно с четными числами, другое с нечетными.
#
# 23. **Фильтрация по условию**: Напишите функцию, которая фильтрует множество, оставляя только те элементы, которые удовлетворяют заданному условию (например, больше 10).
#
# 24. **Проверка на наличие общих элементов**: Напишите функцию, которая проверяет, имеют ли два множества хотя бы один общий элемент.
#
# 25. **Удаление случайного элемента**: Напишите функцию, которая удаляет случайный элемент из множества.
#
# 26. **Генерация множества**: Напишите функцию, которая генерирует множество из `n` случайных чисел в заданном диапазоне.
#
# 27. **Объединение с сохранением порядка**: Напишите функцию, которая объединяет два множества и возвращает результат в виде отсортированного списка.
#
# 28. **Разделение на группы**: Напишите функцию, которая разделяет множество строк на две группы: строки с четной длиной и строки с нечетной длиной.
#
# 29. **Поиск уникальных символов**: Напишите функцию, которая находит уникальные символы в строке с помощью множества.
#
# 30. **Проверка на взаимоисключающие множества**: Напишите функцию, которая проверяет, являются ли два множества взаимоисключающими (т.е. не имеют общих элементов).

# %% [markdown]
# # Tuple

# %% [markdown]
# 1. **Создание кортежа из списка**: Напишите функцию, которая принимает список и возвращает кортеж, содержащий те же элементы.
#
# 2. **Объединение кортежей**: Напишите функцию, которая принимает два кортежа и возвращает их объединение.
#
# 3. **Проверка на наличие элемента**: Напишите функцию, которая проверяет, содержится ли заданный элемент в кортеже.
#
# 4. **Индекс первого вхождения**: Напишите функцию, которая находит индекс первого вхождения заданного элемента в кортеже.
#
# 5. **Количество вхождений элемента**: Напишите функцию, которая подсчитывает, сколько раз заданный элемент встречается в кортеже.
#
# 6. **Максимальный элемент**: Напишите функцию, которая находит максимальный элемент в кортеже.
#
# 7. **Минимальный элемент**: Напишите функцию, которая находит минимальный элемент в кортеже.
#
# 8. **Сортировка кортежа**: Напишите функцию, которая возвращает отсортированный список на основе элементов кортежа.
#
# 9. **Разбиение кортежа**: Напишите функцию, которая разбивает кортеж на две части: первую половину и вторую половину.
#
# 10. **Обратный порядок**: Напишите функцию, которая возвращает кортеж с элементами в обратном порядке.
#
# 11. **Срез кортежа**: Напишите функцию, которая возвращает срез кортежа от заданного начального индекса до конечного.
#
# 12. **Конкатенация кортежей**: Напишите функцию, которая принимает список кортежей и возвращает их конкатенацию в один кортеж.
#
# 13. **Уникальные элементы**: Напишите функцию, которая возвращает множество уникальных элементов кортежа.
#
# 14. **Частота элементов**: Напишите функцию, которая подсчитывает частоту каждого элемента в кортеже.
#
# 15. **Фильтрация по условию**: Напишите функцию, которая фильтрует кортеж, оставляя только те элементы, которые удовлетворяют заданному условию (например, больше 10).
#
# 16. **Сумма элементов**: Напишите функцию, которая вычисляет сумму всех числовых элементов в кортеже.
#
# 17. **Произведение элементов**: Напишите функцию, которая вычисляет произведение всех числовых элементов в кортеже.
#
# 18. **Кортеж из строки**: Напишите функцию, которая преобразует строку в кортеж символов.
#
# 19. **Кортеж из диапазона**: Напишите функцию, которая создает кортеж из чисел в заданном диапазоне.
#
# 20. **Кортеж с повторяющимися элементами**: Напишите функцию, которая создает кортеж, где каждый элемент повторяется заданное количество раз.
#
# 21. **Вложенные кортежи**: Напишите функцию, которая создает вложенный кортеж, где первый уровень — это буквы алфавита, а второй уровень — числа от 1 до 5.
#
# 22. **Развертывание вложенного кортежа**: Напишите функцию, которая разворачивает вложенный кортеж в плоский кортеж.
#
# 23. **Кортеж из двух списков**: Напишите функцию, которая создает кортеж пар из двух списков одинаковой длины.
#
# 24. **Перевод кортежа в строку**: Напишите функцию, которая преобразует кортеж строк в одну строку, объединяя их через пробел.
#
# 25. **Перевод строки в кортеж чисел**: Напишите функцию, которая преобразует строку чисел, разделенных запятыми, в кортеж чисел.
#
# 26. **Кортеж с четными числами**: Напишите функцию, которая создает кортеж, содержащий только четные числа из заданного диапазона.
#
# 27. **Кортеж с нечетными числами**: Напишите функцию, которая создает кортеж, содержащий только нечетные числа из заданного диапазона.
#
# 28. **Кортеж с простыми числами**: Напишите функцию, которая создает кортеж, содержащий только простые числа из заданного диапазона.
#
# 29. **Кортеж с палиндромами**: Напишите функцию, которая создает кортеж, содержащий только строки-палиндромы из заданного списка строк.
#
# 30. **Группировка элементов**: Напишите функцию, которая группирует элементы кортежа по их типам (например, int, str, float) и возвращает словарь, где ключи — это типы, а значения — списки элементов.
